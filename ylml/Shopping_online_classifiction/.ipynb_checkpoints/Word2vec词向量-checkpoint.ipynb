# %% [markdown]
# # Word2vec词向量

# %%
#导入实验所需的工具包
import re
import jieba
import pandas as pd
from gensim.models.word2vec import LineSentence
from gensim.models import Word2Vec
import gensim
import logging
logging.basicConfig(format='%(asctime)s:%(levelname)s:%(message)s',level=logging.INFO)

# %% [markdown]
# ## 数据预处理

# %%
df = pd.read_csv("online_shopping_10_cats.csv")[:60000]
df.head()
# Out:
#   cat  label                                             review
# 0  书籍      1  ﻿做父母一定要有刘墉这样的心态，不断地学习，不断地进步，不断地给自己补充新鲜血液，让自己保持...
# 1  书籍      1  作者真有英国人严谨的风格，提出观点、进行论述论证，尽管本人对物理学了解不深，但是仍然能感受到...
# 2  书籍      1  作者长篇大论借用详细报告数据处理工作和计算结果支持其新观点。为什么荷兰曾经县有欧洲最高的生产...
# 3  书籍      1  作者在战几时之前用了＂拥抱＂令人叫绝．日本如果没有战败，就有会有美军的占领，没胡官僚主义的延...
# 4  书籍      1  作者在少年时即喜阅读，能看出他精读了无数经典，因而他有一个庞大的内心世界。他的作品最难能可贵...

# %%
#使用re正则提取中文并用jieba分词提取词语语料
extract_chinese = re.compile(r'[\u4e00-\u9fa5]+')
chinese_corpus_raw = df['review'].tolist()
chinese_corpus_raw
df['chinese_corpus']=[jieba.lcut("".join(extract_chinese.findall(str(corpus)))) for corpus in chinese_corpus_raw]
df.head()
# Out:
# Building prefix dict from the default dictionary ...
# 2022-06-03 13:45:07,132:DEBUG:Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\23176\AppData\Local\Temp\jieba.cache
# 2022-06-03 13:45:07,135:DEBUG:Loading model from cache C:\Users\23176\AppData\Local\Temp\jieba.cache
# Loading model cost 0.628 seconds.
# 2022-06-03 13:45:07,763:DEBUG:Loading model cost 0.628 seconds.
# Prefix dict has been built successfully.
# 2022-06-03 13:45:07,764:DEBUG:Prefix dict has been built successfully.
#   cat  label                                             review  \
# 0  书籍      1  ﻿做父母一定要有刘墉这样的心态，不断地学习，不断地进步，不断地给自己补充新鲜血液，让自己保持...
# 1  书籍      1  作者真有英国人严谨的风格，提出观点、进行论述论证，尽管本人对物理学了解不深，但是仍然能感受到...
# 2  书籍      1  作者长篇大论借用详细报告数据处理工作和计算结果支持其新观点。为什么荷兰曾经县有欧洲最高的生产...
# 3  书籍      1  作者在战几时之前用了＂拥抱＂令人叫绝．日本如果没有战败，就有会有美军的占领，没胡官僚主义的延...
# 4  书籍      1  作者在少年时即喜阅读，能看出他精读了无数经典，因而他有一个庞大的内心世界。他的作品最难能可贵...
#
#                                       chinese_corpus
# 0  [做, 父母, 一定, 要, 有, 刘墉, 这样, 的, 心态, 不断, 地, 学习, 不断...
# 1  [作者, 真有, 英国人, 严谨, 的, 风格, 提出, 观点, 进行, 论述, 论证, 尽...
# 2  [作者, 长篇大论, 借用, 详细, 报告, 数据处理, 工作, 和, 计算结果, 支持, ...
# 3  [作者, 在, 战, 几时, 之前, 用, 了, 拥抱, 令人, 叫绝, 日本, 如果, 没...
# 4  [作者, 在, 少年, 时即, 喜, 阅读, 能, 看出, 他, 精读, 了, 无数, 经典...

# %%
#将每条评论分词后整合到一个列表中，将每个词用空格隔开放入一个列表中
words_list = []
corpus = []
for corpu in df['chinese_corpus'].tolist():
    words_list.append(corpu)
    corpus.append(' '.join(corpu))
words_list
# Out:
# [['做',
#   '父母',
#   '一定',
#   '要',
#   '有',
#   '刘墉',
#   '这样',
#   '的',
#   '心态',
#   '不断',
#   '地',
#   '学习',
#   '不断',
#   '地',
#   '进步',
#   '不断',
#   '地',
#   '给',
#   '自己',
#   '补充',
#   '新鲜血液',
#   '让',
#   '自己',
#   '保持',
#   '一颗',
#   '年轻',
#   '的',
#   '心',
#   '我',
#   '想',
#   '这',
#   '是',
#   '他',
#   '能',
#   '很',
#   '好',
#   '的',
#   '和',
#   '孩子',
#   '沟通',
#   '的',
#   '一个',
#   '重要',
#   '因素',
#   '读',
#   '刘墉',
#   '的',
#   '文章',
#   '总能',
#   '让',
#   '我',
#   '看到',
#   '一个',
#   '快乐',
#   '的',
#   '平易近人',
#   '的',
#   '父亲',
#   '他',
#   '始终',
#   '站',
#   '在',
#   '和',
#   '孩子',
#   '同样',
#   '的',
#   '高度',
#   '给',
#   '孩子',
#   '创造',
#   '着',
#   '一个',
#   '充满',
#   '爱',
#   '和',
#   '自由',
#   '的',
#   '生活',
#   '环境',
#   '很',
#   '喜欢',
#   '刘墉',
#   '在',
#   '字里行间',
#   '流露出',
#   '的',
#   '做',
#   '父母',
#   '的',
#   '那种',
#   '小',
#   '狡黠',
#   '让',
#   '人',
#   '总是',
#   '忍俊不禁',
#   '父母',
#   '和',
#   '子女',
#   '之间',
#   '有时候',
#   '也',
#   '是',
#   '一种',
#   '战斗',
#   '武力',
#   '争斗',
#   '过于',
#   '低级',
#   '了',
#   '智力',
#   '较量',
#   '才',
#   '更',
#   '有',
#   '趣味',
#   '所以',
#   '做',
#   '父母',
#   '的',
#   '得',
#   '加把劲',
#   '了',
#   '老',
#   '思想',
#   '老',
#   '观念',
#   '注定',
#   '会',
#   '一败涂地',
#   '生命不息',
#   '学习',
#   '不止',
#   '家庭教育',
#   '真的',
#   '是',
#   '乐在其中'],
#  ['作者',
#   '真有',
#   '英国人',
#   '严谨',
#   '的',
#   '风格',
#   '提出',
#   '观点',
#   '进行',
#   '论述',
#   '论证',
#   '尽管',
#   '本人',
#   '对',
#   '物理学',
#   '了解',
#   '不深',
#   '但是',
#   '仍然',
#   '能',
#   '感受',
#   '到',
#   '真理',
#   '的',
#   '火花',
#   '整本书',
#   '的',
#   '结构',
#   '颇',
#   '有',
#   '特点',
#   '从',
#   '当时',
#   '本',
#   '书写',
#   '于',
#   '八十年代',
#   '流行',
#   '的',
#   '计算机',
#   '话题',
#   '引入',
#   '再用',
#   '数学',
#   '物理学',
#   '宇宙学',
#   '做',
#   '必要',
#   '的',
#   '铺垫',
#   '这些',
#   '内容',
#   '占据',
#   '了',
#   '大部分',
#   '篇幅',
#   '最后',
#   '回到',
#   '关键问题',
#   '电脑',
#   '能',
#   '不能',
#   '代替',
#   '人脑',
#   '和',
#   '现在',
#   '流行',
#   '的',
#   '观点',
#   '相反',
#   '作者',
#   '认为',
#   '人',
#   '的',
#   '某种',
#   '洞察',
#   '是',
#   '不能',
#   '被',
#   '算法',
#   '模拟',
#   '的',
#   '也许',
#   '作者',
#   '想',
#   '说',
#   '人',
#   '的',
#   '灵魂',
#   '是',
#   '无可取代',
#   '的'],
#  ['作者',
#   '长篇大论',
#   '借用',
#   '详细',
#   '报告',
#   '数据处理',
#   '工作',
#   '和',
#   '计算结果',
#   '支持',
#   '其新',
#   '观点',
#   '为什么',
#   '荷兰',
#   '曾经',
#   '县有',
#   '欧洲',
#   '最高',
#   '的',
#   '生产率',
#   '为什么',
#   '在',
#   '文化',
#   '上',
#   '有着',
#   '深刻',
#   '纽带',
#   '关系',
#   '的',
#   '中国',
#   '和',
#   '日本',
#   '却',
#   '在',
#   '经济',
#   '发展',
#   '上',
#   '有着',
#   '极大',
#   '的',
#   '差异',
#   '为什么',
#   '英国',
#   '的',
#   '北美',
#   '殖民地',
#   '造就',
#   '了',
#   '经济',
#   '强大',
#   '的',
#   '美国',
#   '而',
#   '西班牙',
#   '的',
#   '北美',
#   '殖民',
#   '却',
#   '造就',
#   '了',
#   '范后',
#   '的',
#   '墨西哥',
#   '很',
#   '有',
#   '价值',
#   '但',
#   '不',
#   '包括',
#   '中国',
#   '近代史',
#   '专业'],
#  ['作者',
#   '在',
#   '战',
#   '几时',
#   '之前',
#   '用',
#   '了',
#   '拥抱',
#   '令人',
#   '叫绝',
#   '日本',
#   '如果',
#   '没有',
#   '战败',
#   '就',
#   '有',
#   '会',
#   '有',
#   '美军',
#   '的',
#   '占领',
#   '没胡',
#   '官僚主义',
#   '的',
#   '延续',
#   '没有',
#   '战后',
#   '的',
#   '民发',
#   '反思',
#   '没有',
#   '就',
#   '不会',
#   '让',
#   '日本',
#   '成为',
#   '一个',
#   '经济',
#   '强国',
#   '当然',
#   '美国',
#   '人',
#   '也',
#   '给',
#   '日本',
#   '人',
#   '带来',
#   '了',
#   '耻辱',
#   '对',
#   '日',
#   '中',
#   '关系',
#   '也',
#   '造成',
#   '了',
#   '深远',
#   '的',
#   '影响',
#   '文中',
#   '揭露',
#   '了',
#   '东京',
#   '审判',
#   '中',
#   '很多',
#   '鲜为人知',
#   '的',
#   '东西',
#   '让',
#   '人',
#   '惊醒',
#   '唉',
#   '中国',
#   '人民',
#   '对',
#   '日本',
#   '的',
#   '了解',
#   '是不是',
#   '太少',
#   '了'],
#  ['作者',
#   '在',
#   '少年',
#   '时即',
#   '喜',
#   '阅读',
#   '能',
#   '看出',
#   '他',
#   '精读',
#   '了',
#   '无数',
#   '经典',
#   '因而',
#   '他',
#   '有',
#   '一个',
#   '庞大',
#   '的',
#   '内心世界',
#   '他',
#   '的',
#   '作品',
#   '最',
#   '难能可贵',
#   '的',
#   '有',
#   '两点',
#   '一是',
#   '他',
#   '的',
#   '理科',
#   '知识',
#   '不错',
#   '虽',
#   '不能',
#   '媲及',
#   '罗素',
#   '但',
#   '与',
#   '理科',
#   '知识',
#   '很差',
#   '的',
#   '作家',
#   '相比',
#   '他',
#   '的',
#   '文章',
#   '可读性',
#   '要强',
#   '其二',
#   '是',
#   '他',
#   '人格',
#   '和',
#   '文风',
#   '的',
#   '朴实',
#   '不',
#   '造作',
#   '不买',
#   '弄',
#   '让',
#   '人',
#   '喜欢',
#   '读',
#   '他',
#   '的',
#   '作品',
#   '犹如',
#   '听',
#   '一个',
#   '好友',
#   '和',
#   '你',
#   '谈心',
#   '常常',
#   '唤起',
#   '心中',
#   '的',
#   '强烈',
#   '的',
#   '共鸣',
#   '他',
#   '的',
#   '作品',
#   '年',
#   '后',
#   '的',
#   '更好',
#   '些',
#   '衷心祝愿',
#   '周国平',
#   '健康',
#   '快乐',
#   '为',
#   '世人',
#   '写出',
#   '更',
#   '多',
#   '好',
#   '作品'],
#  ['作者',
#   '有',
#   '一种',
#   '专业',
#   '的',
#   '谨慎',
#   '若能',
#   '有幸',
#   '学习',
#   '原版',
#   '也许',
#   '会',
#   '更好',
#   '简体版',
#   '的',
#   '书',
#   '中',
#   '的',
#   '印刷错误',
#   '比较',
#   '多',
#   '影响',
#   '学者',
#   '理解',
#   '全书',
#   '结构',
#   '简单',
#   '但',
#   '内容',
#   '详实',
#   '学',
#   '起来',
#   '如鱼得水',
#   '非常',
#   '轻松',
#   '这',
#   '只是',
#   '一项',
#   '技术',
#   '而已',
#   '若',
#   '可以',
#   '结合',
#   '本',
#   '专业',
#   '将会',
#   '得到',
#   '更',
#   '高',
#   '的',
#   '学习',
#   '快乐',
#   '家财万贯',
#   '不如',
#   '一技',
#   '在',
#   '身一技',
#   '在',
#   '身',
#   '不如',
#   '一念',
#   '在',
#   '心',
#   '本书',
#   '有',
#   '不仅',
#   '有技',
#   '而且',
#   '有',
#   '念书',
#   '中',
#   '佳品'],
#  ['作者',
#   '用',
#   '诗',
#   '一样',
#   '的',
#   '语言',
#   '把',
#   '如水般',
#   '清澈',
#   '透明',
#   '的',
#   '思想',
#   '娓娓道来',
#   '像',
#   '一个',
#   '经验丰富',
#   '的',
#   '智慧',
#   '老人',
#   '为',
#   '我们',
#   '解开',
#   '一个',
#   '又',
#   '一个',
#   '人生',
#   '的',
#   '难题',
#   '让',
#   '我们',
#   '超越',
#   '自发',
#   '的',
#   '自己',
#   '和',
#   '世俗',
#   '的',
#   '观念',
#   '引导',
#   '着',
#   '我们',
#   '走向',
#   '光明',
#   '理性',
#   '的',
#   '彼岸',
#   '尤其',
#   '让',
#   '人',
#   '惊叹',
#   '的',
#   '是',
#   '在',
#   '那样',
#   '早',
#   '的',
#   '年代',
#   '作者',
#   '对',
#   '一些',
#   '心理',
#   '问题',
#   '居然',
#   '有',
#   '那样',
#   '深',
#   '的',
#   '体会',
#   '对',
#   '一些',
#   '人生',
#   '问题',
#   '能够',
#   '分析',
#   '得',
#   '那样',
#   '的',
#   '深刻',
#   '透彻',
#   '确实',
#   '是',
#   '非常',
#   '难能可贵',
#   '的',
#   '较',
#   '之前',
#   '一本',
#   '罗马',
#   '皇帝',
#   '的',
#   '沉思',
#   '录',
#   '不知',
#   '要',
#   '高明',
#   '多少倍',
#   '直如',
#   '天壤之别'],
#  ['作者',
#   '提出',
#   '了',
#   '一种',
#   '工作',
#   '和',
#   '生活',
#   '的',
#   '方式',
#   '作为',
#   '咨询',
#   '界',
#   '的',
#   '元老',
#   '不仅',
#   '能',
#   '提出',
#   '理念',
#   '而且',
#   '能够',
#   '身体力行',
#   '地',
#   '实践',
#   '并且',
#   '提出',
#   '具体',
#   '的',
#   '步骤',
#   '展现',
#   '的',
#   '是',
#   '一种',
#   '自然',
#   '的',
#   '生活态度',
#   '一种',
#   '劳役',
#   '结合',
#   '张弛',
#   '有度',
#   '的',
#   '生活',
#   '方式',
#   '作者',
#   '提出',
#   '的',
#   '观点',
#   '引入',
#   '了',
#   '欧美人',
#   '乐观',
#   '的',
#   '生活',
#   '方式',
#   '并且',
#   '结合',
#   '现在',
#   '日本',
#   '的',
#   '社会',
#   '状况',
#   '和',
#   '生存环境',
#   '提出',
#   '了',
#   '一种',
#   '切实可行',
#   '的',
#   '生活',
#   '历程',
#   '其实',
#   '这些',
#   '观点',
#   '同样',
#   '也',
#   '适用',
#   '于',
#   '现在',
#   '正在',
#   '步',
#   '日本',
#   '后尘',
#   '的',
#   '中国',
#   '人会',
#   '玩',
#   '才',
#   '会',
#   '幸福'],
#  ['作者',
#   '妙语连珠',
#   '将',
#   '整个',
#   '年代',
#   '用',
#   '层出不穷',
#   '的',
#   '摇滚',
#   '巨星',
#   '与',
#   '自身',
#   '故事',
#   '紧紧',
#   '相连',
#   '什么',
#   '是',
#   '乡愁',
#   '什么',
#   '是',
#   '摇滚',
#   '那',
#   '是',
#   '一种',
#   '特立独行',
#   '看似',
#   '高傲',
#   '实则',
#   '温暖',
#   '的',
#   '姿态',
#   '那',
#   '是',
#   '一种',
#   '绝世独立',
#   '下',
#   '深深',
#   '的',
#   '孤单',
#   '与',
#   '不甘',
#   '文字',
#   '和',
#   '音乐',
#   '当',
#   '两种',
#   '忧愁',
#   '相互',
#   '碰撞',
#   '的',
#   '时候',
#   '才',
#   '会',
#   '激起',
#   '读者',
#   '心中',
#   '的',
#   '相同',
#   '感受',
#   '无论',
#   '何时',
#   '世界',
#   '在',
#   '变',
#   '我们',
#   '的',
#   '偶像',
#   '在',
#   '慢慢',
#   '老去',
#   '那个',
#   '曾经',
#   '年华',
#   '不老',
#   '的',
#   '时代',
#   '已然',
#   '飘',
#   '去',
#   '于是',
#   '摇滚',
#   '成',
#   '了',
#   '最让人',
#   '痛彻',
#   '心扉',
#   '的',
#   '蓝调'],
#  ['作者',
#   '逻辑',
#   '严密',
#   '一气呵成',
#   '没有',
#   '一句',
#   '废话',
#   '深入浅出',
#   '循循善诱',
#   '环环相扣',
#   '让',
#   '平日',
#   '里',
#   '看到',
#   '指标',
#   '图释',
#   '就',
#   '头疼',
#   '的',
#   '我',
#   '竟然',
#   '大有',
#   '拨云见日',
#   '醍醐灌顶',
#   '之感果',
#   '不出所料',
#   '占豪',
#   '的',
#   '黄金',
#   '游戏',
#   '值得',
#   '期待'],
#  ['作者',
#   '力',
#   '从',
#   '马克思',
#   '注意',
#   '经济学',
#   '角度',
#   '来',
#   '剖析',
#   '当代',
#   '中国',
#   '经济',
#   '细心',
#   '的',
#   '人会',
#   '发现',
#   '中国',
#   '近年来',
#   '的',
#   '一些',
#   '政策措施',
#   '在',
#   '何新',
#   '先生',
#   '的',
#   '文章',
#   '里',
#   '找到',
#   '蛛丝马迹',
#   '作者',
#   '早',
#   '在',
#   '年',
#   '就',
#   '预言',
#   '十年',
#   '内',
#   '世界',
#   '会',
#   '爆发',
#   '大规模',
#   '金融危机',
#   '这',
#   '非常',
#   '难得',
#   '原因',
#   '来自',
#   '与',
#   '作者',
#   '本人',
#   '的',
#   '数据',
#   '统计',
#   '及其',
#   '严密',
#   '的',
#   '逻辑推理',
#   '能',
#   '与',
#   '国家',
#   '发展',
#   '大计',
#   '作为',
#   '自己',
#   '重任',
#   '的',
#   '知识分子',
#   '现在',
#   '并',
#   '不多见',
#   '了',
#   '看看',
#   '那些',
#   '上市公司',
#   '的',
#   '独立',
#   '懂事',
#   '就',
#   '知道',
#   '了',
#   '我',
#   '认为',
#   '何先生',
#   '是',
#   '了不起',
#   '的',
#   '知识分子'],
#  ['作者',
#   '结合',
#   '希尔',
#   '和',
#   '卡耐基',
#   '汪中求',
#   '等',
#   '大师',
#   '的',
#   '一些',
#   '观点',
#   '结合',
#   '中国',
#   '的',
#   '实际',
#   '情况',
#   '给',
#   '渴望',
#   '成功',
#   '的',
#   '青年',
#   '指出',
#   '一条',
#   '实实在在',
#   '的',
#   '路',
#   '我',
#   '也',
#   '看过',
#   '不少',
#   '成功',
#   '学',
#   '著作',
#   '只有',
#   '这',
#   '本书',
#   '的',
#   '作者',
#   '是',
#   '企业家',
#   '感觉',
#   '他',
#   '说',
#   '得',
#   '比较',
#   '实在',
#   '其实',
#   '我们',
#   '也',
#   '不',
#   '指望',
#   '成功',
#   '就',
#   '一定',
#   '要',
#   '和',
#   '比尔盖茨',
#   '比能',
#   '实现',
#   '自己',
#   '的',
#   '小小',
#   '梦想',
#   '就行',
#   '如果说',
#   '希尔',
#   '等',
#   '人',
#   '的',
#   '著作',
#   '是',
#   '习武',
#   '的',
#   '总纲',
#   '还',
#   '需要',
#   '你',
#   '研究',
#   '推敲',
#   '一下',
#   '那',
#   '这',
#   '本书',
#   '就是',
#   '本',
#   '武林',
#   '秘笈',
#   '你',
#   '只要',
#   '照着',
#   '练就',
#   '行',
#   '了',
#   '至于',
#   '成龙',
#   '成虫',
#   '就',
#   '看',
#   '你',
#   '练',
#   '得',
#   '如何'],
#  ['作者',
#   '更',
#   '多',
#   '的',
#   '是从',
#   '圆圆',
#   '母亲',
#   '的',
#   '角度',
#   '来',
#   '写',
#   '这个',
#   '文章',
#   '的',
#   '例子',
#   '都',
#   '是',
#   '以',
#   '圆圆',
#   '为',
#   '中心',
#   '的',
#   '我',
#   '认为',
#   '例证',
#   '不够',
#   '充分',
#   '毕竟',
#   '每个',
#   '孩子',
#   '都',
#   '很',
#   '不',
#   '一样',
#   '而且',
#   '很',
#   '明显',
#   '虽然',
#   '作者',
#   '一再强调',
#   '是',
#   '教育',
#   '的',
#   '原因',
#   '但',
#   '不可否认',
#   '圆圆的',
#   '聪明',
#   '和',
#   '乖巧',
#   '也',
#   '是',
#   '有目共睹',
#   '的',
#   '换个',
#   '男孩',
#   '肯定',
#   '是',
#   '没有',
#   '这么',
#   '轻松',
#   '的',
#   '总的来说',
#   '作者',
#   '列举',
#   '的',
#   '都',
#   '是',
#   '一些',
#   '生活',
#   '中',
#   '的',
#   '例子',
#   '确实',
#   '很',
#   '有',
#   '代表性',
#   '教育',
#   '方向',
#   '及',
#   '思路',
#   '非常',
#   '明确',
#   '应该',
#   '学习',
#   '一个',
#   '好',
#   '妈妈',
#   '的',
#   '教育',
#   '笔记',
#   '可以',
#   '推荐',
#   '给',
#   '家中',
#   '迂腐',
#   '的',
#   '老人'],
#  ['作者',
#   '对于',
#   '某些',
#   '电影',
#   '表面',
#   '粗糙',
#   '内里',
#   '光滑',
#   '的',
#   '分析',
#   '可谓',
#   '入木三分',
#   '为',
#   '理解',
#   '那些',
#   '貌似',
#   '触及',
#   '现实',
#   '而',
#   '又',
#   '让',
#   '人',
#   '觉得',
#   '哪里',
#   '不对劲',
#   '的',
#   '影片',
#   '提供',
#   '了',
#   '一个',
#   '清醒',
#   '的',
#   '视角',
#   '这个',
#   '角度',
#   '在',
#   '导演',
#   '来说',
#   '也许',
#   '是',
#   '讳莫如深',
#   '的',
#   '也许',
#   '是',
#   '不',
#   '自觉',
#   '的',
#   '而',
#   '不管',
#   '是',
#   '回避',
#   '还是',
#   '无意识',
#   '这种',
#   '对于',
#   '现状',
#   '的',
#   '屈服',
#   '都',
#   '是',
#   '有害',
#   '于',
#   '艺术',
#   '真诚',
#   '的',
#   '或者',
#   '他们',
#   '所',
#   '做',
#   '本来',
#   '就',
#   '与',
#   '艺术',
#   '无关'],
#  ['作者',
#   '的',
#   '理念',
#   '很',
#   '好',
#   '主要',
#   '是',
#   '看',
#   '一个',
#   '公司',
#   '的',
#   '内部',
#   '情况',
#   '来',
#   '决定',
#   '股票',
#   '的',
#   '情况',
#   '操作',
#   '比较',
#   '难',
#   '作者',
#   '也',
#   '承认',
#   '所以',
#   '他',
#   '说',
#   '还是',
#   '让',
#   '基金',
#   '经理',
#   '来',
#   '做',
#   '书',
#   '中',
#   '的',
#   '事情',
#   '吧',
#   '对',
#   '我',
#   '启发',
#   '不是',
#   '在于',
#   '买',
#   '股票',
#   '而且',
#   '如何',
#   '做',
#   '企业',
#   '如何',
#   '培养',
#   '员工',
#   '我',
#   '想',
#   '刚',
#   '毕业',
#   '找',
#   '工作',
#   '的',
#   '学生',
#   '应该',
#   '看看',
#   '你',
#   '到底',
#   '应该',
#   '区',
#   '一个',
#   '什么样',
#   '的',
#   '企业',
#   '工作',
#   '以后',
#   '会当',
#   '老板',
#   '的',
#   '也',
#   '应该',
#   '看看',
#   '如何',
#   '对待',
#   '员工',
#   '如何',
#   '对待',
#   '企业',
#   '等等',
#   '作为',
#   '股票',
#   '类',
#   '的',
#   '书',
#   '我',
#   '觉得',
#   '应该',
#   '是',
#   '三星',
#   '但',
#   '它',
#   '给',
#   '了',
#   '我',
#   '其它',
#   '方面',
#   '的',
#   '启发',
#   '所以',
#   '加',
#   '了',
#   '一个',
#   '星'],
#  ['作者',
#   '的',
#   '观点',
#   '独特',
#   '语言',
#   '犀利',
#   '深刻',
#   '的',
#   '总结',
#   '了',
#   '男人',
#   '与',
#   '女人',
#   '之间',
#   '的',
#   '是非',
#   '恩怨',
#   '把',
#   '男人',
#   '与',
#   '女人',
#   '在生活中',
#   '积累',
#   '的',
#   '宿怨',
#   '一语道破',
#   '原来',
#   '非本质',
#   '问题',
#   '而是',
#   '双方',
#   '本能',
#   '此书',
#   '不足之处',
#   '乃',
#   '后面',
#   '章节',
#   '雷同',
#   '越',
#   '看',
#   '越',
#   '有',
#   '寡味',
#   '之感',
#   '但是',
#   '还是',
#   '要',
#   '感谢',
#   '作者',
#   '带',
#   '我们',
#   '游览',
#   '一次',
#   '男人',
#   '女人',
#   '的',
#   '本能',
#   '世界',
#   '呵呵',
#   '建议',
#   '读者',
#   '可以',
#   '看一看',
#   '有则改之',
#   '无则加勉'],
#  ['作者',
#   '的',
#   '笔触',
#   '很',
#   '真实',
#   '将',
#   '一个',
#   '不忠',
#   '却',
#   '又',
#   '深爱',
#   '自己',
#   '妻子',
#   '的',
#   '丈夫',
#   '形象',
#   '毫无',
#   '遮掩',
#   '的',
#   '展示',
#   '给',
#   '读者',
#   '而',
#   '什么',
#   '是',
#   '真爱',
#   '什么',
#   '是',
#   '灵魂',
#   '的',
#   '永远',
#   '缠绕',
#   '相守',
#   '是',
#   '看过',
#   '这',
#   '本书',
#   '的',
#   '人',
#   '不得不',
#   '思考',
#   '的',
#   '问题',
#   '在',
#   '这',
#   '本书',
#   '中',
#   '了解',
#   '了',
#   '生命',
#   '将',
#   '逝',
#   '却',
#   '无能为力',
#   '所',
#   '承受',
#   '的',
#   '艰辛',
#   '对',
#   '安乐死',
#   '也',
#   '有些',
#   '了解',
#   '最后',
#   '章节',
#   '的',
#   '那句',
#   '我们',
#   '已经',
#   '不再',
#   '相信',
#   '坏',
#   '运气',
#   '了',
#   '坏',
#   '运气',
#   '不',
#   '存在',
#   '运气',
#   '不',
#   '存在',
#   '相信',
#   '运气',
#   '是',
#   '对',
#   '生命',
#   '的',
#   '侮辱',
#   '多么',
#   '坚韧',
#   '的',
#   '人性',
#   '之美'],
#  ['作者',
#   '笔下留情',
#   '啊',
#   '深圳',
#   '的',
#   '自由',
#   '作家',
#   '远远',
#   '没有',
#   '离婚',
#   '未遂',
#   '笔下',
#   '那么',
#   '潇洒',
#   '事实上',
#   '深圳',
#   '是',
#   '一个',
#   '典型',
#   '的',
#   '伪',
#   '文化',
#   '城市',
#   '没有',
#   '文学院',
#   '歌舞团',
#   '被',
#   '解散',
#   '越剧团',
#   '正',
#   '解散',
#   '深圳',
#   '不是',
#   '文人',
#   '的',
#   '立身',
#   '之地',
#   '啊',
#   '但是',
#   '小说',
#   '确实',
#   '不错',
#   '所以',
#   '我',
#   '仍然',
#   '强烈推荐'],
#  ['作者',
#   '被',
#   '认为',
#   '是',
#   '爱',
#   '的',
#   '奇迹',
#   '天使',
#   '确实',
#   '是',
#   '这样',
#   '的',
#   '很多',
#   '人',
#   '认为',
#   '与',
#   '孩子',
#   '的',
#   '相处',
#   '一定',
#   '充满',
#   '快乐',
#   '但',
#   '却',
#   '不知',
#   '一份',
#   '责任',
#   '让',
#   '这种',
#   '快乐',
#   '有时',
#   '并不一定',
#   '以',
#   '微笑',
#   '的',
#   '方式',
#   '出现',
#   '作者',
#   '很',
#   '真实',
#   '的',
#   '反映',
#   '了',
#   '与',
#   '孩子',
#   '相处',
#   '中',
#   '的',
#   '真实',
#   '虽然',
#   '是',
#   '在读',
#   '她',
#   '的',
#   '故事',
#   '却',
#   '感觉',
#   '心',
#   '和',
#   '她',
#   '在',
#   '一起',
#   '同样',
#   '的',
#   '我',
#   '很',
#   '庆幸',
#   '自己',
#   '从事',
#   '一份',
#   '与',
#   '孩子',
#   '生活',
#   '的',
#   '工作',
#   '这',
#   '工作',
#   '让',
#   '我',
#   '拥有',
#   '美妙',
#   '的',
#   '人生'],
#  ['作为',
#   '有史以来',
#   '最',
#   '伟大',
#   '的',
#   '基金',
#   '经理',
#   '彼得',
#   '林奇',
#   '凭借',
#   '其',
#   '在',
#   '投资',
#   '领域',
#   '杰出',
#   '的',
#   '贡献',
#   '终其一生',
#   '的',
#   '经验',
#   '和',
#   '智慧',
#   '书写',
#   '了',
#   '这本',
#   '彼得',
#   '林奇',
#   '的',
#   '成功',
#   '投资',
#   '这',
#   '本书',
#   '可以',
#   '说',
#   '是',
#   '广大',
#   '的',
#   '业余',
#   '投资者',
#   '的',
#   '福音书',
#   '中',
#   '不仅',
#   '讲述',
#   '了',
#   '业余',
#   '投资者',
#   '投资',
#   '入门',
#   '的',
#   '基础知识',
#   '而且',
#   '还',
#   '深刻',
#   '精辟',
#   '的',
#   '分析',
#   '了',
#   '业余',
#   '投资者',
#   '最',
#   '常见',
#   '的',
#   '投资',
#   '心理',
#   '误区',
#   '以及',
#   '投资',
#   '陷阱',
#   '等',
#   '是',
#   '一套',
#   '最',
#   '实用',
#   '最',
#   '有效',
#   '的',
#   '股票投资',
#   '方面',
#   '的',
#   '专业书籍',
#   '让',
#   '人',
#   '读后',
#   '深受',
#   '启发'],
#  ['作为',
#   '一名',
#   '山西',
#   '太谷',
#   '人',
#   '从小',
#   '听',
#   '多',
#   '了',
#   '有关',
#   '晋商',
#   '的',
#   '故事',
#   '也',
#   '去过',
#   '许多',
#   '山西',
#   '的',
#   '地方',
#   '但',
#   '由于',
#   '离家',
#   '已',
#   '久',
#   '故乡',
#   '渐渐',
#   '地',
#   '模糊起来',
#   '不是',
#   '山水',
#   '而是',
#   '那',
#   '一段段',
#   '历史',
#   '想',
#   '向',
#   '人',
#   '推荐',
#   '或',
#   '向',
#   '人',
#   '解说',
#   '却',
#   '尴尬',
#   '的',
#   '发现',
#   '有',
#   '许多',
#   '东西',
#   '已记',
#   '不',
#   '准确',
#   '近年来',
#   '走',
#   '的',
#   '地方',
#   '多',
#   '发现',
#   '对于',
#   '他',
#   '乡',
#   '的',
#   '知识',
#   '已',
#   '超过',
#   '故乡',
#   '于是',
#   '诚惶诚',
#   '怕',
#   '的',
#   '找',
#   '来',
#   '故乡',
#   '的',
#   '相关',
#   '书籍',
#   '进行',
#   '系统',
#   '的',
#   '复习',
#   '这',
#   '本书',
#   '对',
#   '各地',
#   '的',
#   '介绍',
#   '虽然',
#   '不够',
#   '详细',
#   '但',
#   '这种',
#   '风格',
#   '及',
#   '语言',
#   '却是',
#   '我',
#   '非常',
#   '喜欢',
#   '的',
#   '它',
#   '使',
#   '我',
#   '重温',
#   '了',
#   '记忆',
#   '中',
#   '的',
#   '故乡',
#   '增强',
#   '了',
#   '我',
#   '对',
#   '故乡',
#   '历史',
#   '的',
#   '熟悉',
#   '更',
#   '增加',
#   '了',
#   '一种',
#   '作为',
#   '客居',
#   '异乡',
#   '的',
#   '山西人',
#   '的',
#   '自豪',
#   '我',
#   '希望',
#   '能',
#   '跟着',
#   '本书',
#   '的',
#   '脚步',
#   '去',
#   '重新',
#   '游走',
#   '故乡',
#   '的',
#   '山水'],
#  ['作为',
#   '一名',
#   '白骨精',
#   '我',
#   '不得不',
#   '佩服',
#   '作者',
#   '入木三分',
#   '的',
#   '刻画',
#   '不仅',
#   '精准',
#   '地',
#   '描绘出',
#   '我们',
#   '的',
#   '生活',
#   '画面',
#   '更',
#   '深刻',
#   '地',
#   '揭露',
#   '了',
#   '我们',
#   '内心',
#   '的',
#   '挣扎',
#   '与',
#   '困顿',
#   '确实',
#   '是',
#   '一部',
#   '当代',
#   '白骨精',
#   '们',
#   '的',
#   '写照',
#   '写出',
#   '了',
#   '职场',
#   '的',
#   '竞争',
#   '写出',
#   '了',
#   '雇佣',
#   '与',
#   '被',
#   '雇佣',
#   '的',
#   '现实',
#   '笔锋',
#   '平实',
#   '清澈',
#   '是',
#   '好',
#   '作品',
#   '看着',
#   '看着',
#   '便',
#   '感觉',
#   '自己',
#   '也',
#   '渐渐',
#   '地',
#   '深入',
#   '到',
#   '这个',
#   '故事',
#   '中',
#   '和',
#   '你',
#   '一起',
#   '在职',
#   '场中',
#   '打拼',
#   '在',
#   '感情',
#   '中',
#   '沉浮',
#   '泪',
#   '也',
#   '一次',
#   '又',
#   '一次',
#   '地润',
#   '了',
#   '眼眶'],
#  ['作为',
#   '一本',
#   '职场',
#   '启示录',
#   '不错',
#   '没有',
#   '像',
#   '杜',
#   '拉拉',
#   '一样',
#   '的',
#   '引入',
#   '胜',
#   '的',
#   '故事',
#   '却',
#   '也',
#   '用',
#   '轻松',
#   '的',
#   '方式',
#   '告诉',
#   '你',
#   '如何',
#   '在职',
#   '场中',
#   '生存',
#   '如何',
#   '能越',
#   '爬越',
#   '高用',
#   '简洁明了',
#   '的',
#   '图形',
#   '模式',
#   '刻画出',
#   '了',
#   '身',
#   '在职',
#   '场所',
#   '需',
#   '的',
#   '职场',
#   '氦气',
#   '让',
#   '人',
#   '跃跃欲试',
#   '至于',
#   '为什么',
#   '要',
#   '叫',
#   '星巴克',
#   '职场',
#   '启示录',
#   '个人',
#   '认为',
#   '有',
#   '一点',
#   '打广告',
#   '的',
#   '嫌疑',
#   '在',
#   '里面',
#   '跟',
#   '似乎',
#   '没有',
#   '太',
#   '大',
#   '牵连',
#   '美中不足',
#   '有些',
#   '地方',
#   '的',
#   '阐述',
#   '不够',
#   '详尽',
#   '需要',
#   '自己',
#   '不断',
#   '揣磨'],
#  ['作为',
#   '一本',
#   '屹立',
#   '不倒',
#   '的',
#   '经典',
#   '教材',
#   '纽摄',
#   '所',
#   '传授',
#   '的',
#   '不是',
#   '单纯',
#   '的',
#   '技术',
#   '而是',
#   '理念',
#   '不是',
#   '教条',
#   '的',
#   '灌输',
#   '而是',
#   '互动性',
#   '的',
#   '思考',
#   '从书',
#   '的',
#   '内容',
#   '上',
#   '品评',
#   '虽说',
#   '部分',
#   '内容',
#   '对于',
#   '数码影像',
#   '发达',
#   '的',
#   '今天',
#   '有些',
#   '过时',
#   '但是',
#   '摄影',
#   '作为',
#   '一门',
#   '技术性',
#   '行业',
#   '的',
#   '本质',
#   '是',
#   '不会',
#   '变',
#   '的',
#   '对于',
#   '摄影',
#   '的',
#   '创作',
#   '人',
#   '的',
#   '理念',
#   '才',
#   '是',
#   '造就',
#   '一张',
#   '好',
#   '照片',
#   '的',
#   '决定',
#   '所在',
#   '在',
#   '当今',
#   '这个',
#   '各种',
#   '所谓',
#   '的',
#   '主题',
#   '摄影',
#   '泛滥',
#   '的',
#   '时代',
#   '什么',
#   '才',
#   '是',
#   '我们',
#   '真正',
#   '乐于',
#   '接受',
#   '的',
#   '好',
#   '照片',
#   '呢',
#   '值得',
#   '回到',
#   '原点',
#   '去',
#   '思索'],
#  ['作为',
#   '一本',
#   '西方人',
#   '创作',
#   '的',
#   '心理学',
#   '读物',
#   '还是',
#   '以',
#   '西方人',
#   '的',
#   '视角',
#   '来',
#   '看待',
#   '问题',
#   '的',
#   '方式',
#   '来',
#   '阐述',
#   '目前',
#   '刚刚开始',
#   '读',
#   '但是',
#   '感觉',
#   '到',
#   '作者',
#   '对',
#   '事物',
#   '的',
#   '描述',
#   '还是',
#   '偏',
#   '西方化',
#   '的',
#   '西方人',
#   '观察',
#   '事物',
#   '喜欢',
#   '抓',
#   '重点',
#   '而',
#   '东方人',
#   '的',
#   '习惯',
#   '比较',
#   '抓',
#   '整体',
#   '这是',
#   '开始',
#   '读',
#   '这本',
#   '读物',
#   '的',
#   '感觉',
#   '不过',
#   '西方',
#   '的',
#   '开放式',
#   '教育',
#   '模式',
#   '给',
#   '这本',
#   '重点',
#   '教材',
#   '添加',
#   '了',
#   '无与伦比',
#   '的',
#   '趣味性',
#   '和',
#   '我国',
#   '的',
#   '教材',
#   '体制',
#   '有',
#   '明显',
#   '的',
#   '不同',
#   '个人',
#   '认为',
#   '还是',
#   '非常',
#   '值得',
#   '一读',
#   '的',
#   '好书'],
#  ['作为',
#   '推理小说',
#   '可能',
#   '不是',
#   '最好',
#   '的',
#   '作为',
#   '言情小说',
#   '可能',
#   '也',
#   '不是',
#   '最好',
#   '的',
#   '但是',
#   '结合',
#   '在',
#   '一起',
#   '却',
#   '很',
#   '让',
#   '人',
#   '惊奇',
#   '羡慕',
#   '那样',
#   '的',
#   '爱情',
#   '和',
#   '那样',
#   '的',
#   '生活',
#   '也许',
#   '所有',
#   '的',
#   '杀人犯',
#   '都',
#   '有',
#   '自己',
#   '很',
#   '心酸',
#   '的',
#   '一段',
#   '生活',
#   '一段',
#   '历程',
#   '那',
#   '是',
#   '一种',
#   '常人',
#   '所',
#   '无法',
#   '理解',
#   '的',
#   '痛苦',
#   '和',
#   '无助',
#   '如果',
#   '他们',
#   '能',
#   '得到',
#   '一份',
#   '爱',
#   '也许',
#   '真的',
#   '会',
#   '有',
#   '更好',
#   '的',
#   '生活',
#   '元元',
#   '和',
#   '陆劲',
#   '的',
#   '爱情',
#   '能',
#   '有情人终成眷属',
#   '真的',
#   '是',
#   '一件',
#   '很',
#   '欣慰',
#   '的',
#   '事情',
#   '无论',
#   '生活',
#   '在',
#   '什么',
#   '地方',
#   '什么',
#   '环境',
#   '的',
#   '人',
#   '都',
#   '要',
#   '找到',
#   '自己',
#   '能',
#   '付出',
#   '可以',
#   '付出',
#   '一切',
#   '的',
#   '那个',
#   '人'],
#  ['作为',
#   '女儿',
#   '的',
#   '礼物',
#   '虽然',
#   '晚到',
#   '了',
#   '几天',
#   '等',
#   '拿到',
#   '的',
#   '时候',
#   '女儿',
#   '爱不释手',
#   '上',
#   '洗手间',
#   '也',
#   '看',
#   '告知',
#   '不好',
#   '竟以',
#   '学习',
#   '毛主席',
#   '来',
#   '反驳',
#   '我',
#   '我',
#   '反对',
#   '了',
#   '几句',
#   '还',
#   '说',
#   '我',
#   '对',
#   '主席',
#   '不敬晕',
#   '上周末',
#   '告诉',
#   '我',
#   '她',
#   '把',
#   '火鞋',
#   '和',
#   '风鞋',
#   '拿到',
#   '学校',
#   '好多',
#   '同学',
#   '羡慕',
#   '她',
#   '呵呵',
#   '我',
#   '也',
#   '看',
#   '了',
#   '其中',
#   '的',
#   '人鸦',
#   '只',
#   '可惜',
#   '没有',
#   '看',
#   '完',
#   '就',
#   '在',
#   '老公',
#   '的',
#   '催促',
#   '下',
#   '睡',
#   '了',
#   '说',
#   '了',
#   '这么',
#   '多',
#   '归纳',
#   '为',
#   '一句',
#   '这',
#   '套书',
#   '买',
#   '的',
#   '值'],
#  ['作为',
#   '妈妈',
#   '我',
#   '个人',
#   '很',
#   '喜欢',
#   '这',
#   '本书',
#   '但是',
#   '仍',
#   '在',
#   '怀疑',
#   '这',
#   '本书',
#   '是否',
#   '适合',
#   '给',
#   '孩子',
#   '看',
#   '这',
#   '本书',
#   '以',
#   '孩子',
#   '的',
#   '视角',
#   '观看',
#   '我们',
#   '的',
#   '生活',
#   '并',
#   '以',
#   '幽默',
#   '的',
#   '口吻',
#   '讲述',
#   '实在',
#   '有趣',
#   '又',
#   '发人深省',
#   '对于',
#   '经常',
#   '加班',
#   '感到',
#   '疲惫',
#   '的',
#   '我',
#   '最近',
#   '拿',
#   '这',
#   '本书',
#   '作为',
#   '精神',
#   '放松',
#   '和',
#   '愉悦',
#   '心灵',
#   '的',
#   '良品',
#   '睡',
#   '前',
#   '看',
#   '一段',
#   '总',
#   '忍不住',
#   '呵呵',
#   '地轻',
#   '笑',
#   '而',
#   '同时',
#   '不必',
#   '刻意',
#   '就',
#   '反省',
#   '到',
#   '了',
#   '自己',
#   '如同',
#   '尼古拉',
#   '的',
#   '父母',
#   '一般',
#   '同样',
#   '存在',
#   '着',
#   '很多',
#   '可笑',
#   '的',
#   '自我',
#   '矛盾',
#   '呢',
#   '这',
#   '本书',
#   '好像',
#   '给',
#   '大人',
#   '的',
#   '教育',
#   '意义',
#   '更大些',
#   '呢',
#   '呵呵'],
#  ['昨晚',
#   '看着',
#   '看着',
#   '就',
#   '睡着',
#   '了',
#   '今天',
#   '早晨',
#   '醒来',
#   '就',
#   '立马',
#   '抓起',
#   '继续',
#   '啃',
#   '正逢',
#   '小说',
#   '结尾',
#   '部分',
#   '也',
#   '正如',
#   '作者',
#   '的',
#   '期望',
#   '我',
#   '被',
#   '吓了一跳',
#   '这',
#   '是',
#   '我',
#   '读',
#   '东野',
#   '圭',
#   '吾',
#   '小说',
#   '最',
#   '意料不到',
#   '的',
#   '事实',
#   '爱有',
#   '很',
#   '多种',
#   '可是',
#   '当',
#   '它',
#   '变成',
#   '某种',
#   '负担',
#   '时',
#   '还',
#   '算',
#   '爱',
#   '吗',
#   '爱',
#   '有',
#   '多种',
#   '表现形式',
#   '当',
#   '某种',
#   '行为',
#   '让',
#   '对方',
#   '感觉',
#   '负罪',
#   '时',
#   '这',
#   '还',
#   '能',
#   '叫做',
#   '爱',
#   '吗',
#   '爱',
#   '可以',
#   '很',
#   '长久',
#   '当',
#   '这种',
#   '永恒',
#   '变成',
#   '一种',
#   '恶梦',
#   '时',
#   '还',
#   '能',
#   '归于',
#   '最初',
#   '的',
#   '爱',
#   '吗',
#   '爱',
#   '可以',
#   '深入骨髓',
#   '无法',
#   '割除',
#   '当',
#   '它',
#   '接受',
#   '无法',
#   '预知',
#   '的',
#   '变数',
#   '时',
#   '还',
#   '能',
#   '始终如一',
#   '吗'],
#  ['昨天',
#   '我',
#   '把',
#   '这',
#   '套书',
#   '看',
#   '完',
#   '了',
#   '结尾',
#   '我',
#   '不是',
#   '很',
#   '喜欢',
#   '有点',
#   '太',
#   '戏剧',
#   '了',
#   '但',
#   '对',
#   '书',
#   '中',
#   '的',
#   '主人公',
#   '却是',
#   '最好',
#   '的',
#   '安排',
#   '我',
#   '去过',
#   '新疆',
#   '但是',
#   '因为',
#   '时间',
#   '太短',
#   '加之',
#   '新疆',
#   '的',
#   '地域',
#   '有点',
#   '过于',
#   '广阔',
#   '所以',
#   '好多',
#   '的',
#   '地方',
#   '都',
#   '没',
#   '去',
#   '成',
#   '看',
#   '完',
#   '这',
#   '本书',
#   '之后',
#   '我',
#   '又',
#   '有',
#   '了',
#   '去',
#   '新疆',
#   '的',
#   '念头',
#   '也',
#   '因为',
#   '深深',
#   '的',
#   '喜欢',
#   '上',
#   '了',
#   '这个',
#   '帅哥',
#   '和尚',
#   '也',
#   '找',
#   '了',
#   '几本',
#   '佛经',
#   '看看',
#   '就是',
#   '有点',
#   '看不懂',
#   '慢慢来',
#   '吧',
#   '小春',
#   '继续',
#   '你',
#   '的',
#   '写作',
#   '我',
#   '支持',
#   '你'],
#  ['昨天晚上',
#   '看',
#   '完',
#   '了',
#   '此书',
#   '揭开',
#   '了',
#   '猎头',
#   '的',
#   '神秘',
#   '面纱',
#   '将',
#   '猎头',
#   '与',
#   '的',
#   '运作',
#   '展现',
#   '在',
#   '人们',
#   '面前',
#   '以',
#   '小说',
#   '的',
#   '形式',
#   '将',
#   '猎头',
#   '的',
#   '工作',
#   '展现',
#   '开来',
#   '期间',
#   '穿插',
#   '有关',
#   '猎头',
#   '的',
#   '叙述',
#   '受益匪浅',
#   '主人公',
#   '是',
#   '一个',
#   '极富',
#   '正义感',
#   '的',
#   '信守',
#   '承诺',
#   '的',
#   '优秀',
#   '的',
#   '有',
#   '才华',
#   '的',
#   '人物',
#   '他',
#   '看穿',
#   '了',
#   '世事',
#   '的',
#   '虚浮',
#   '寻找',
#   '着',
#   '一片',
#   '宁静',
#   '的',
#   '内心世界',
#   '故事',
#   '结尾',
#   '又',
#   '未免',
#   '过于',
#   '伤感',
#   '失去',
#   '至亲至爱',
#   '的',
#   '人',
#   '表现',
#   '出来',
#   '他',
#   '最最',
#   '脆弱',
#   '的',
#   '一面',
#   '仿佛',
#   '感受',
#   '到',
#   '他',
#   '撕心裂肺',
#   '的',
#   '伤痛',
#   '期待',
#   '续',
#   '的',
#   '出版'],
#  ['昨天',
#   '带',
#   '宝宝',
#   '在',
#   '朋友',
#   '的',
#   '小区',
#   '玩有',
#   '工人',
#   '正在',
#   '植树',
#   '宝宝',
#   '目不转睛',
#   '地',
#   '观察',
#   '着',
#   '妈妈',
#   '告诉',
#   '宝宝',
#   '他们',
#   '正在',
#   '种树',
#   '呢',
#   '宝宝',
#   '没有',
#   '吭声',
#   '过',
#   '了',
#   '一会儿',
#   '爸爸',
#   '过来',
#   '了',
#   '爸爸',
#   '问',
#   '他们',
#   '在',
#   '干什么',
#   '宝宝',
#   '说',
#   '他们',
#   '正在',
#   '挖',
#   '宝藏',
#   '哈哈',
#   '宝宝',
#   '准是',
#   '想起',
#   '了',
#   '弗洛',
#   '格带',
#   '着',
#   '小熊',
#   '一起',
#   '挖',
#   '宝藏',
#   '的',
#   '故事',
#   '感谢',
#   '可爱',
#   '的',
#   '小',
#   '青蛙',
#   '弗洛',
#   '格给',
#   '了',
#   '宝宝',
#   '丰富',
#   '的',
#   '想象力',
#   '一个',
#   '多彩',
#   '美丽',
#   '的',
#   '世界'],
#  ['最',
#   '真实',
#   '与',
#   '实用',
#   '的',
#   '白领',
#   '成长',
#   '故事',
#   '也',
#   '是',
#   '目前为止',
#   '我',
#   '所读',
#   '过',
#   '的',
#   '最',
#   '深刻',
#   '的',
#   '白领',
#   '生活',
#   '工作',
#   '的',
#   '总结',
#   '看',
#   '了',
#   '不但',
#   '受益匪浅',
#   '而且',
#   '觉得',
#   '过瘾',
#   '振奋',
#   '为',
#   '中国',
#   '有',
#   '这样',
#   '优秀',
#   '的',
#   '打',
#   '工人',
#   '而',
#   '自豪',
#   '看',
#   '了',
#   '确实',
#   '有',
#   '让',
#   '我',
#   '回忆',
#   '最多',
#   '的',
#   '却',
#   '不是',
#   '人生旅途',
#   '里',
#   '这些',
#   '成功',
#   '的',
#   '瞬间',
#   '而是',
#   '那些',
#   '刻骨铭心',
#   '的',
#   '失败',
#   '或',
#   '挫折',
#   '它',
#   '展示',
#   '地是',
#   '一个',
#   '真实',
#   '与',
#   '真诚',
#   '的',
#   '人',
#   '一个',
#   '真心',
#   '与',
#   '你',
#   '分享',
#   '如何',
#   '才能',
#   '成功',
#   '而',
#   '不是',
#   '一个',
#   '天才',
#   '的',
#   '故事',
#   '打工',
#   '的',
#   '神仙',
#   '强烈推荐'],
#  ['最早',
#   '认识',
#   '张曼娟',
#   '是',
#   '在',
#   '张清芳',
#   '的',
#   '上边',
#   '作为',
#   '一位',
#   '写',
#   '词人',
#   '细腻',
#   '的',
#   '文字',
#   '连',
#   '歌词',
#   '也',
#   '写',
#   '得',
#   '像',
#   '情书',
#   '小',
#   '女人',
#   '的',
#   '楚楚',
#   '婉婉',
#   '后来',
#   '才',
#   '知道',
#   '张曼娟',
#   '也',
#   '是',
#   '作家',
#   '于是',
#   '开始',
#   '计划',
#   '读',
#   '她',
#   '的',
#   '书',
#   '挑',
#   '了',
#   '这本',
#   '很',
#   '奇怪',
#   '的',
#   '名字',
#   '张曼娟',
#   '妖物',
#   '志写',
#   '妖物',
#   '也',
#   '写',
#   '人',
#   '最',
#   '喜欢',
#   '里边',
#   '的',
#   '永恒',
#   '遗失',
#   '女螺',
#   '张曼娟',
#   '的',
#   '文字',
#   '没有',
#   '讲过',
#   '大道理',
#   '但是',
#   '留有',
#   '思考',
#   '的',
#   '余地',
#   '也许',
#   '错身',
#   '未知',
#   '也许',
#   '缄封',
#   '成秘',
#   '也许',
#   '不愿',
#   '承认',
#   '妖物',
#   '活在',
#   '你',
#   '心里'],
#  ['最早',
#   '接触',
#   '寂地',
#   '画',
#   '是',
#   '在',
#   '新蕾',
#   '上',
#   '后来',
#   '满心欢喜',
#   '的',
#   '买',
#   '了',
#   '她',
#   '的',
#   '第一本',
#   '画集',
#   '我',
#   '的',
#   '路',
#   '很',
#   '喜欢',
#   '那种',
#   '温暖',
#   '的',
#   '画风',
#   '也',
#   '很',
#   '喜欢',
#   '配画',
#   '的',
#   '文字',
#   '很',
#   '细腻',
#   '有',
#   '哲理',
#   '让',
#   '人',
#   '感觉',
#   '温馨',
#   '后来',
#   '她',
#   '出',
#   '的',
#   '每',
#   '一期',
#   '都',
#   '买',
#   '了',
#   '回来',
#   '用',
#   '四叶草',
#   '的',
#   '包书',
#   '纸包',
#   '好',
#   '这次',
#   '这',
#   '一套',
#   '买',
#   '了',
#   '是',
#   '给',
#   '朋友',
#   '的',
#   '朋友',
#   '看到',
#   '我',
#   '有',
#   '一套',
#   '我',
#   '的',
#   '路',
#   '也',
#   '很',
#   '想要',
#   '所以',
#   '让',
#   '我',
#   '帮',
#   '她',
#   '买',
#   '开始',
#   '会',
#   '担心',
#   '里面',
#   '的',
#   '附赠品',
#   '不',
#   '知道',
#   '会',
#   '不会',
#   '有',
#   '看来',
#   '是',
#   '有',
#   '的',
#   '朋友',
#   '收到',
#   '了',
#   '很',
#   '开心',
#   '也',
#   '很',
#   '喜欢'],
#  ['最有',
#   '价值',
#   '的',
#   '就是',
#   '支撑',
#   '压力',
#   '背后',
#   '的',
#   '东西',
#   '以及',
#   '趋势',
#   '的',
#   '定义',
#   '至于',
#   '后面',
#   '的',
#   '波浪理论',
#   '以及',
#   '江恩',
#   '理论',
#   '这些',
#   '东西',
#   '都',
#   '不是',
#   '大师',
#   '的',
#   '实战',
#   '技术',
#   '而是',
#   '股市',
#   '失败者',
#   '的',
#   '作品',
#   '不但',
#   '没有',
#   '意义',
#   '反而',
#   '有害',
#   '不过',
#   '总体',
#   '上书',
#   '还是',
#   '不错',
#   '的',
#   '经过',
#   '完整',
#   '牛',
#   '熊市',
#   '后',
#   '感觉',
#   '学习',
#   '炒股',
#   '最',
#   '重要',
#   '就是',
#   '阅读',
#   '长时间',
#   '股市',
#   '成功者',
#   '自己',
#   '写',
#   '的',
#   '书',
#   '其他人',
#   '总结',
#   '的',
#   '书',
#   '都',
#   '是',
#   '垃圾',
#   '不但',
#   '没有',
#   '好处',
#   '反而',
#   '有害'],
#  ['最喜歡',
#   '這部',
#   '雖然',
#   '很',
#   '是',
#   '賺',
#   '走',
#   '了',
#   '我',
#   '的',
#   '眼淚',
#   '發現',
#   '自己',
#   '越來',
#   '越愛看',
#   '這些',
#   '悲情',
#   '的',
#   '讓',
#   '人',
#   '揪心',
#   '疼痛',
#   '的',
#   '文字',
#   '匪大',
#   '的',
#   '確是',
#   '後',
#   '媽來',
#   '的',
#   '東子',
#   '對',
#   '佳期',
#   '的',
#   '愛是',
#   '絕對',
#   '獨一無二',
#   '的',
#   '可是',
#   '真愛的',
#   '未必',
#   '能',
#   '在',
#   '一起',
#   '記得',
#   '那句',
#   '那',
#   '時候',
#   '年',
#   '輕什麼',
#   '都',
#   '沒',
#   '有',
#   '可是',
#   '有勇',
#   '氣現',
#   '在',
#   '的',
#   '自己',
#   '已經',
#   '是',
#   '連勇氣',
#   '都',
#   '沒',
#   '有',
#   '了',
#   '只能',
#   '看著',
#   '這樣',
#   '的',
#   '小',
#   '說',
#   '慰籍',
#   '自己',
#   '愛',
#   '就是',
#   '那麼',
#   '不圓滿',
#   '要',
#   '看',
#   '得',
#   '開放得',
#   '下',
#   '難',
#   '啊',
#   '難'],
#  ['最',
#   '喜欢',
#   '里面',
#   '兔子',
#   '招惹',
#   '外星人',
#   '还有',
#   '兔子',
#   '摞',
#   '起来',
#   '和',
#   '貌似',
#   '一',
#   '武侠',
#   '比武',
#   '的',
#   '那',
#   '篇',
#   '太',
#   '有意思',
#   '了',
#   '我',
#   '把',
#   '它',
#   '拿给',
#   '室友',
#   '看',
#   '她',
#   '居然',
#   '说',
#   '画',
#   '这',
#   '本书',
#   '的',
#   '人',
#   '思想',
#   '有',
#   '问题',
#   '不禁',
#   '让',
#   '我',
#   '想起',
#   '前',
#   '几天',
#   '在',
#   '手机',
#   '报中',
#   '看到',
#   '的',
#   '关于',
#   '心理',
#   '抑郁症',
#   '的',
#   '说法',
#   '如果',
#   '看',
#   '完',
#   '找死',
#   '的',
#   '兔子',
#   '笑',
#   '的',
#   '前仰后合',
#   '说明',
#   '我们',
#   '的',
#   '心理',
#   '是',
#   '健康',
#   '的',
#   '我',
#   '很',
#   '同意',
#   '哈哈',
#   '因为',
#   '我',
#   '的确',
#   '看得',
#   '很',
#   '过瘾',
#   '很',
#   '开心',
#   '佩服',
#   '作者',
#   '的',
#   '奇思妙想',
#   '衷心希望',
#   '心情',
#   '总是',
#   '不好',
#   '的',
#   '人们',
#   '能够',
#   '笑对人生',
#   '其实',
#   '真',
#   '没什么',
#   '过不去',
#   '的',
#   '坎儿'],
#  ['最',
#   '开心',
#   '的',
#   '阅读',
#   '莫过于',
#   '你',
#   '看',
#   '的',
#   '书',
#   '和',
#   '你',
#   '自己',
#   '的',
#   '生活',
#   '阅历',
#   '有',
#   '异曲同工',
#   '的',
#   '地方',
#   '常常',
#   '在',
#   '看书',
#   '的',
#   '时候',
#   '我要',
#   '拍案叫绝',
#   '遥想',
#   '写',
#   '这',
#   '本书',
#   '的',
#   '时候',
#   '作者',
#   '是',
#   '在',
#   '年',
#   '而',
#   '我',
#   '自己',
#   '的',
#   '心理',
#   '发展',
#   '从',
#   '年',
#   '到',
#   '年',
#   '居然',
#   '在',
#   '很多',
#   '地方',
#   '应验',
#   '了',
#   '他',
#   '的',
#   '理论',
#   '说明',
#   '读',
#   '他',
#   '的',
#   '书',
#   '对',
#   '有',
#   '心理',
#   '困惑',
#   '或',
#   '力求',
#   '完善',
#   '心理',
#   '人格',
#   '的',
#   '朋友',
#   '是',
#   '绝对',
#   '有益',
#   '的',
#   '比',
#   '我',
#   '同时',
#   '买',
#   '的',
#   '那本',
#   '一岁',
#   '就',
#   '上',
#   '常青藤',
#   '要',
#   '好',
#   '上',
#   '几百倍'],
#  ['最',
#   '开始',
#   '是',
#   '在',
#   '机场',
#   '等',
#   '飞机',
#   '时',
#   '发现',
#   '这',
#   '本书',
#   '的',
#   '觉得',
#   '特别',
#   '好',
#   '就',
#   '一直',
#   '站',
#   '着',
#   '在',
#   '那里',
#   '读',
#   '因为',
#   '机场',
#   '不',
#   '打折',
#   '所以',
#   '回家',
#   '后',
#   '就',
#   '第一',
#   '时间',
#   '在',
#   '当当',
#   '上',
#   '买',
#   '了',
#   '这',
#   '本书',
#   '读过',
#   '她',
#   '的',
#   '好多',
#   '书',
#   '喜欢',
#   '她',
#   '也',
#   '喜欢',
#   '她',
#   '的',
#   '书',
#   '知性',
#   '的',
#   '美丽',
#   '成功',
#   '的',
#   '自信',
#   '但',
#   '只有',
#   '真正',
#   '读过',
#   '她',
#   '的',
#   '书',
#   '才',
#   '知道',
#   '所以',
#   '成功',
#   '后面',
#   '也',
#   '有',
#   '付出',
#   '所有',
#   '付出',
#   '都',
#   '会',
#   '有',
#   '回报',
#   '女人',
#   '的',
#   '美会',
#   '有',
#   '很',
#   '多种',
#   '但',
#   '作者',
#   '的',
#   '美丽',
#   '不但',
#   '因为',
#   '青春',
#   '流逝',
#   '而',
#   '减少',
#   '忙碌',
#   '的',
#   '工作',
#   '和',
#   '生活',
#   '之外',
#   '看看',
#   '这',
#   '本书',
#   '会',
#   '让',
#   '你',
#   '思考',
#   '很多'],
#  ['最近',
#   '在读',
#   '第二遍',
#   '这',
#   '本书',
#   '似乎',
#   '更',
#   '详细',
#   '的',
#   '在',
#   '展示',
#   '各种',
#   '斗争',
#   '分析',
#   '的',
#   '很',
#   '透彻',
#   '很',
#   '明白',
#   '有',
#   '很多',
#   '道理',
#   '都',
#   '是',
#   '很',
#   '好',
#   '的',
#   '比如',
#   '不是',
#   '敌人',
#   '是',
#   '双赢',
#   '但是',
#   '最后',
#   '的',
#   '感觉',
#   '是',
#   '这',
#   '本书',
#   '太',
#   '细节',
#   '了',
#   '整整',
#   '一',
#   '本书',
#   '也',
#   '没有',
#   '写',
#   '完',
#   '一个',
#   '故事',
#   '这',
#   '让',
#   '我',
#   '有时',
#   '觉得',
#   '有点烦',
#   '虽然',
#   '知道',
#   '实际',
#   '中',
#   '的',
#   '情况',
#   '要',
#   '比书中',
#   '更加',
#   '复杂',
#   '但是',
#   '还是',
#   '不想',
#   '如此',
#   '仔细',
#   '的',
#   '看',
#   '一个',
#   '故事',
#   '看',
#   '这个',
#   '书',
#   '时会',
#   '累',
#   '因为',
#   '真的',
#   '不想',
#   '如此',
#   '复杂',
#   '太',
#   '复杂',
#   '了',
#   '我',
#   '不是',
#   '那种',
#   '复杂',
#   '斗争',
#   '的',
#   '人'],
#  ['最近',
#   '有点',
#   '忙',
#   '直到',
#   '昨天晚上',
#   '读完',
#   '了',
#   '整部书',
#   '我',
#   '震撼',
#   '了',
#   '特别',
#   '是',
#   '读',
#   '到',
#   '小',
#   '狼',
#   '要',
#   '要',
#   '迁移',
#   '的',
#   '时候',
#   '我',
#   '才',
#   '明白',
#   '什么',
#   '是',
#   '倔强',
#   '什么',
#   '叫',
#   '桀骜不驯',
#   '那',
#   '到底',
#   '是',
#   '一种',
#   '什么样',
#   '的',
#   '性格',
#   '直到',
#   '陈陈',
#   '不得不',
#   '亲手',
#   '杀死',
#   '小狼',
#   '的',
#   '时候',
#   '我',
#   '几乎',
#   '也',
#   '差点',
#   '哭',
#   '出来',
#   '人',
#   '狼',
#   '这',
#   '是',
#   '一种',
#   '什么样',
#   '的',
#   '感情',
#   '就',
#   '像',
#   '别人',
#   '给',
#   '的',
#   '评论',
#   '一样',
#   '狼图腾',
#   '让',
#   '人们',
#   '勇于',
#   '承认',
#   '人们',
#   '自身',
#   '潜在',
#   '的',
#   '弱点',
#   '而',
#   '当今社会',
#   '人们',
#   '迫切需要',
#   '的',
#   '不',
#   '正是',
#   '应该',
#   '像',
#   '狼',
#   '那样',
#   '的',
#   '性格',
#   '吗',
#   '这',
#   '真是',
#   '一部',
#   '奇书'],
#  ['最近',
#   '因为',
#   '忙',
#   '着',
#   '准备',
#   '考试',
#   '所以',
#   '没有',
#   '看太多',
#   '不过',
#   '禁不住',
#   '巨大',
#   '的',
#   '诱惑',
#   '看',
#   '了',
#   '一些',
#   '了',
#   '我',
#   '看',
#   '完',
#   '了',
#   '贝拉',
#   '篇',
#   '雅各布',
#   '篇',
#   '看到',
#   '了',
#   '第二章',
#   '这',
#   '样子',
#   '的',
#   '写法',
#   '挺',
#   '有意思',
#   '的',
#   '虽然',
#   '已经',
#   '习惯',
#   '了',
#   '是',
#   '以',
#   '贝拉',
#   '的',
#   '角度',
#   '来看',
#   '但是',
#   '这',
#   '样子',
#   '仔细',
#   '看看',
#   '狼人',
#   '的',
#   '想法',
#   '也',
#   '蛮',
#   '不错',
#   '的',
#   '真的',
#   '是',
#   '很',
#   '好看',
#   '但是',
#   '现在',
#   '看着',
#   '就',
#   '觉得',
#   '有',
#   '的',
#   '时候',
#   '真的',
#   '是',
#   '挺',
#   '离谱',
#   '的',
#   '呵呵',
#   '不过',
#   '我',
#   '还是',
#   '没',
#   '搞清楚',
#   '到底',
#   '这个',
#   '结局',
#   '是不是',
#   '在',
#   '这',
#   '本书',
#   '里',
#   '出现',
#   '加油',
#   '啦',
#   '好看',
#   '好看',
#   '好看'],
#  ['最近',
#   '一直',
#   '在',
#   '看',
#   '这',
#   '本书',
#   '我',
#   '觉得',
#   '很',
#   '好',
#   '当初',
#   '只是',
#   '想',
#   '看看',
#   '南怀瑾',
#   '但',
#   '又',
#   '没',
#   '耐心',
#   '去',
#   '一本',
#   '本地',
#   '买',
#   '毕竟',
#   '南怀瑾',
#   '先生',
#   '的',
#   '书',
#   '都',
#   '是',
#   '讲课',
#   '的',
#   '内容',
#   '比较',
#   '罗嗦',
#   '于是',
#   '就',
#   '挑',
#   '了',
#   '这本',
#   '集',
#   '南怀瑾',
#   '先生',
#   '佛道',
#   '儒',
#   '各种',
#   '见解',
#   '的',
#   '书',
#   '开始',
#   '的',
#   '时候',
#   '确实',
#   '冲着',
#   '南怀瑾',
#   '去',
#   '的',
#   '但',
#   '现在',
#   '不是',
#   '了',
#   '作者',
#   '的',
#   '见解',
#   '很',
#   '简洁',
#   '很明',
#   '了',
#   '让',
#   '我',
#   '很',
#   '容易接受',
#   '并且',
#   '我们',
#   '看法',
#   '一致',
#   '也许',
#   '这',
#   '不是',
#   '一本',
#   '让',
#   '人',
#   '可以',
#   '看了又看',
#   '的',
#   '书',
#   '却是',
#   '一本',
#   '让',
#   '人',
#   '一见如故',
#   '的',
#   '书',
#   '这',
#   '就',
#   '够',
#   '了'],
#  ['最近',
#   '一直',
#   '在',
#   '看',
#   '昨天',
#   '一口气',
#   '看',
#   '了',
#   '章',
#   '建议',
#   '怀孕',
#   '末期',
#   '的',
#   '准爸',
#   '准妈们',
#   '都',
#   '买',
#   '本来',
#   '看看',
#   '通过',
#   '这',
#   '本书',
#   '了解',
#   '了',
#   '孩子',
#   '的',
#   '一些',
#   '行为',
#   '其实',
#   '孩子',
#   '的',
#   '一些',
#   '行为',
#   '不',
#   '一定',
#   '就是',
#   '老人',
#   '嘴里',
#   '说',
#   '的',
#   '那样',
#   '孩子',
#   '每个',
#   '动作',
#   '都',
#   '是',
#   '主动',
#   '得',
#   '表达',
#   '自己',
#   '得',
#   '情感',
#   '和',
#   '感觉',
#   '作为',
#   '父母',
#   '只有',
#   '了解',
#   '了',
#   '孩子',
#   '的',
#   '真实',
#   '感受',
#   '才能',
#   '更好',
#   '的',
#   '跟',
#   '孩子',
#   '沟通',
#   '虽然',
#   '我',
#   '还',
#   '没',
#   '看',
#   '完',
#   '但',
#   '我',
#   '觉得',
#   '孙',
#   '老师',
#   '说',
#   '的',
#   '真的',
#   '非常',
#   '有',
#   '道理',
#   '里面',
#   '的',
#   '许多',
#   '个案',
#   '在',
#   '我',
#   '儿子',
#   '的',
#   '身上',
#   '都',
#   '有所',
#   '体现'],
#  ['最近',
#   '写',
#   '了',
#   '一篇',
#   '此书',
#   '的',
#   '读后感',
#   '发表',
#   '在',
#   '报纸',
#   '上',
#   '估计',
#   '主编',
#   '发表',
#   '他',
#   '是因为',
#   '他',
#   '没有',
#   '看过',
#   '这',
#   '本书',
#   '其实',
#   '想',
#   '让',
#   '大家',
#   '没事',
#   '来',
#   '看看',
#   '这',
#   '本书',
#   '我',
#   '可不是',
#   '托',
#   '啊',
#   '只是',
#   '世纪',
#   '现代',
#   '作家',
#   '的',
#   '作品',
#   '大家',
#   '目前',
#   '读',
#   '的',
#   '不',
#   '多',
#   '但',
#   '这些',
#   '作家',
#   '的',
#   '作品',
#   '却是',
#   '非常',
#   '值得',
#   '关注',
#   '的',
#   '这',
#   '本书',
#   '的',
#   '印刷',
#   '很',
#   '好',
#   '翻译',
#   '也',
#   '算',
#   '到位',
#   '每篇',
#   '似乎',
#   '都',
#   '有',
#   '可供',
#   '书写',
#   '的',
#   '空白',
#   '地带',
#   '你',
#   '看',
#   '完',
#   '可以',
#   '随手',
#   '在',
#   '书上',
#   '写写画画',
#   '看',
#   '完书',
#   '能够',
#   '在',
#   '自己',
#   '的',
#   '书上',
#   '题字',
#   '议论',
#   '不亦快',
#   '哉'],
#  ['最近',
#   '受',
#   '几位',
#   '老年大学',
#   '学友',
#   '的',
#   '委托',
#   '又',
#   '购买',
#   '了',
#   '几本',
#   '数码单反',
#   '摄影',
#   '轻松',
#   '入门',
#   '和',
#   '完全',
#   '解析',
#   '确实',
#   '很',
#   '不错'],
#  ['最近',
#   '感觉',
#   '生活',
#   '特别',
#   '累',
#   '所以',
#   '就',
#   '买',
#   '了',
#   '几本书',
#   '来',
#   '读少',
#   '有人',
#   '走',
#   '的',
#   '路',
#   '这',
#   '本书',
#   '刚',
#   '开始',
#   '读前',
#   '几章',
#   '时',
#   '感觉',
#   '自己',
#   '的',
#   '心情',
#   '豁然开朗',
#   '心情',
#   '放松',
#   '了',
#   '许多',
#   '对于',
#   '工作',
#   '对于',
#   '生活',
#   '又',
#   '有',
#   '了',
#   '信心',
#   '随着',
#   '后面',
#   '几章',
#   '的',
#   '阅读',
#   '感觉',
#   '这',
#   '本书',
#   '有',
#   '很多',
#   '地方',
#   '好像',
#   '有话',
#   '没有',
#   '说',
#   '明白',
#   '的',
#   '感觉',
#   '感觉',
#   '作者',
#   '总是',
#   '把',
#   '问题',
#   '阐述',
#   '一半',
#   '就',
#   '接着',
#   '进行',
#   '阐述',
#   '下面',
#   '一个',
#   '问题',
#   '了',
#   '不过',
#   '总体',
#   '感觉',
#   '还是',
#   '很',
#   '振奋人心',
#   '的',
#   '可以',
#   '启迪',
#   '人生',
#   '有',
#   '时间',
#   '再',
#   '读',
#   '一遍',
#   '古人',
#   '说',
#   '温故而知新',
#   '嘛'],
#  ['最近',
#   '杜',
#   '拉拉',
#   '被',
#   '炒',
#   '得',
#   '很',
#   '火',
#   '很多',
#   '人',
#   '说',
#   '她',
#   '是',
#   '职场',
#   '新人',
#   '的',
#   '指南',
#   '不过',
#   '我',
#   '觉得',
#   '带',
#   '着',
#   '一种',
#   '平静',
#   '而',
#   '恬淡',
#   '的',
#   '心情',
#   '来',
#   '看待',
#   '这',
#   '本书',
#   '也许',
#   '更',
#   '合适',
#   '一点',
#   '可能',
#   '是',
#   '工作',
#   '性质',
#   '的',
#   '原因',
#   '我',
#   '并',
#   '没有',
#   '受益匪浅',
#   '的',
#   '感觉',
#   '平心而论',
#   '说',
#   '它',
#   '是',
#   '一本',
#   '新型',
#   '的',
#   '职场',
#   '小说',
#   '应该',
#   '来',
#   '的',
#   '更为',
#   '贴切',
#   '对于',
#   '小说',
#   '的',
#   '高潮',
#   '部分',
#   '似乎',
#   '是',
#   '点到为止',
#   '总',
#   '觉得',
#   '有点',
#   '意犹未尽',
#   '不过',
#   '在',
#   '看',
#   '的',
#   '过程',
#   '中',
#   '整个',
#   '心情',
#   '还是',
#   '很',
#   '不错',
#   '的'],
#  ['最近',
#   '不知',
#   '怎么回事',
#   '出',
#   '了',
#   '很多',
#   '后宫',
#   '方面',
#   '的',
#   '书',
#   '看',
#   '得',
#   '我',
#   '这',
#   '叫',
#   '郁闷',
#   '早就',
#   '关注',
#   '大心',
#   '的',
#   '这本',
#   '了',
#   '看到',
#   '上架',
#   '了',
#   '马上',
#   '订货',
#   '还好',
#   '第二天',
#   '就',
#   '送到',
#   '了',
#   '结果',
#   '看到',
#   '凌晨',
#   '点',
#   '为了',
#   '还',
#   '能',
#   '睁',
#   '着眼',
#   '上班',
#   '必须',
#   '眯',
#   '几个',
#   '小时',
#   '一句',
#   '话',
#   '太',
#   '好看',
#   '了',
#   '怎么',
#   '能',
#   '这么',
#   '好看',
#   '我',
#   '也',
#   '是',
#   '一直',
#   '看大心',
#   '的',
#   '结局',
#   '这次',
#   '可能',
#   '为了',
#   '出版',
#   '吧',
#   '还是',
#   '有些',
#   '遗憾',
#   '看过',
#   '大心',
#   '的',
#   '色遍',
#   '后',
#   '就',
#   '觉得',
#   '无法比拟',
#   '的',
#   '好看',
#   '真',
#   '希望',
#   '能',
#   '出版',
#   '啊'],
#  ['最后',
#   '一章',
#   '是',
#   '专门',
#   '解读',
#   '儿童',
#   '经络',
#   '的',
#   '温馨',
#   '实用',
#   '之前',
#   '买',
#   '的',
#   '那本',
#   '送给',
#   '了',
#   '新',
#   '得',
#   '了',
#   '宝宝',
#   '的',
#   '亲戚',
#   '自己',
#   '再藏',
#   '一本',
#   '继续',
#   '学习',
#   '看到',
#   '有',
#   '不少',
#   '人',
#   '在',
#   '车上',
#   '看书',
#   '毕竟',
#   '颠簸',
#   '还是',
#   '避免',
#   '吧',
#   '祝愿',
#   '大家',
#   '都',
#   '受益'],
#  ['最好',
#   '是',
#   '三本',
#   '一起',
#   '看',
#   '藏獒',
#   '主要',
#   '是',
#   '写',
#   '藏獒',
#   '与',
#   '狼',
#   '的',
#   '惊心动魄',
#   '的',
#   '搏斗',
#   '场面',
#   '非常',
#   '的',
#   '宏大',
#   '壮观',
#   '情节',
#   '很',
#   '吸引',
#   '人',
#   '在',
#   '藏獒',
#   '救人',
#   '的',
#   '情节',
#   '中有',
#   '很多',
#   '感人',
#   '的',
#   '事迹',
#   '让',
#   '人',
#   '不由得',
#   '黯然泪下',
#   '真的',
#   '很',
#   '向往',
#   '在',
#   '西',
#   '结古',
#   '草原',
#   '上',
#   '的',
#   '藏獒',
#   '勇敢',
#   '机灵',
#   '忠诚',
#   '永远都是',
#   '先人后己',
#   '无所畏惧',
#   '的',
#   '牺牲',
#   '自己',
#   '特别',
#   '是',
#   '大黑',
#   '獒',
#   '那日',
#   '真的',
#   '是',
#   '让',
#   '人',
#   '感动',
#   '赞叹',
#   '还有',
#   '很多很多',
#   '的',
#   '藏獒',
#   '们',
#   '为了',
#   '人类',
#   '牺牲',
#   '了',
#   '自己',
#   '品格高尚',
#   '的',
#   '藏獒',
#   '们',
#   '是',
#   '大自然',
#   '赐给',
#   '人类',
#   '的',
#   '精灵'],
#  ['最初',
#   '因为',
#   '书名',
#   '所',
#   '吸引',
#   '曾',
#   '有',
#   '一个',
#   '人爱',
#   '我',
#   '如',
#   '生命',
#   '这是',
#   '怎样',
#   '的',
#   '一种',
#   '爱',
#   '这样',
#   '的',
#   '爱',
#   '是',
#   '太过',
#   '沉重',
#   '还是',
#   '刻骨铭心',
#   '带',
#   '着',
#   '这种',
#   '疑问',
#   '用',
#   '了',
#   '大半天',
#   '的',
#   '时间',
#   '看',
#   '完',
#   '心里',
#   '有种',
#   '说不上来',
#   '的',
#   '难受',
#   '相爱',
#   '的',
#   '两个',
#   '人',
#   '竟然',
#   '连',
#   '最后',
#   '一面',
#   '都',
#   '没有',
#   '见到',
#   '就',
#   '阴阳',
#   '两隔',
#   '这份',
#   '遗憾',
#   '很',
#   '喜欢',
#   '书',
#   '封面',
#   '上',
#   '的话',
#   '如果',
#   '当初',
#   '我',
#   '勇敢',
#   '结局',
#   '是不是',
#   '不',
#   '一样',
#   '如果',
#   '当时',
#   '你',
#   '坚持',
#   '回忆',
#   '会',
#   '不会',
#   '不',
#   '这样'],
#  ['最初',
#   '看到',
#   '这',
#   '本书',
#   '随手',
#   '拿',
#   '起来',
#   '翻',
#   '了',
#   '翻',
#   '就',
#   '被',
#   '其中',
#   '一个个',
#   '很',
#   '精彩',
#   '的',
#   '小',
#   '故事',
#   '所',
#   '吸引',
#   '然然',
#   '每个',
#   '故事',
#   '后面',
#   '还会',
#   '附上',
#   '相关',
#   '的',
#   '道理',
#   '在',
#   '其中',
#   '读',
#   '起来',
#   '感觉',
#   '是',
#   '一次',
#   '心灵',
#   '的',
#   '洗涮',
#   '让',
#   '我们',
#   '学会',
#   '以',
#   '更好',
#   '的',
#   '心态',
#   '看待',
#   '生活',
#   '中',
#   '发生地',
#   '种种',
#   '人情世故',
#   '身处',
#   '在',
#   '繁忙',
#   '都市',
#   '中',
#   '的',
#   '人们',
#   '很多',
#   '时候',
#   '大多',
#   '忽略',
#   '了',
#   '这些',
#   '最',
#   '平凡',
#   '最',
#   '简单',
#   '的',
#   '幸福',
#   '和',
#   '快乐',
#   '而',
#   '这',
#   '本书',
#   '就是',
#   '很',
#   '好',
#   '的',
#   '把',
#   '大家',
#   '遗忘',
#   '的',
#   '幸福快乐',
#   '罗列',
#   '出来',
#   '释放',
#   '心灵',
#   '的',
#   '枷锁',
#   '获取',
#   '真正',
#   '的',
#   '快乐',
#   '和',
#   '幸福',
#   '吧'],
#  ['最初',
#   '看',
#   '门第',
#   '是',
#   '在',
#   '报纸',
#   '的',
#   '连载',
#   '上',
#   '也',
#   '是',
#   '我',
#   '第一次',
#   '看连谏',
#   '的',
#   '小说',
#   '从',
#   '看',
#   '了',
#   '第一集',
#   '就',
#   '被',
#   '它',
#   '深深',
#   '吸引',
#   '其实',
#   '里面',
#   '的',
#   '很多',
#   '故事',
#   '很多',
#   '情节',
#   '和',
#   '场景',
#   '都',
#   '是',
#   '发生',
#   '在',
#   '我们',
#   '自己',
#   '身上',
#   '只是',
#   '我们',
#   '深思',
#   '过后',
#   '发出',
#   '一声',
#   '无奈',
#   '的',
#   '叹息',
#   '然后',
#   '继续',
#   '生活',
#   '罢了',
#   '当然',
#   '经过',
#   '之后',
#   '我们',
#   '还会',
#   '发展',
#   '事情',
#   '往往',
#   '不会',
#   '坏到',
#   '哪里',
#   '去',
#   '的',
#   '太阳',
#   '还会',
#   '每日',
#   '东升',
#   '和煦',
#   '的',
#   '晚风',
#   '也',
#   '会',
#   '如期而至',
#   '过日子',
#   '就是',
#   '这样'],
#  ['最初',
#   '读',
#   '是',
#   '在',
#   '小学',
#   '的',
#   '时候',
#   '看',
#   '了',
#   '一遍',
#   '心中',
#   '不禁',
#   '澎湃',
#   '万分',
#   '却',
#   '只是',
#   '儿时',
#   '对',
#   '英雄',
#   '的',
#   '向往',
#   '初中',
#   '时',
#   '又',
#   '重读',
#   '了',
#   '一遍',
#   '初步',
#   '认识',
#   '了',
#   '什么',
#   '是',
#   '人间',
#   '的',
#   '善',
#   '与',
#   '恶赏',
#   '与',
#   '罚',
#   '高中',
#   '忙于',
#   '考大学',
#   '虽',
#   '无暇顾及',
#   '但',
#   '在',
#   '紧张',
#   '之余',
#   '却',
#   '可',
#   '拿来',
#   '玩味',
#   '现如今',
#   '上',
#   '了',
#   '大学',
#   '时间',
#   '重新',
#   '多',
#   '了',
#   '起来',
#   '买来',
#   '一本',
#   '仿佛',
#   '回到',
#   '了',
#   '少年',
#   '却',
#   '又',
#   '能',
#   '用',
#   '更加',
#   '成熟',
#   '的',
#   '心态',
#   '去',
#   '审视',
#   '品研',
#   '不管',
#   '是',
#   '印刷',
#   '还是',
#   '排版',
#   '都',
#   '很',
#   '好',
#   '我',
#   '看',
#   '你',
#   '这',
#   '字体',
#   '很',
#   '不错',
#   '紧凑',
#   '但',
#   '不',
#   '拥挤',
#   '看着',
#   '不',
#   '费力',
#   '的'],
#  ['纵然',
#   '是',
#   '再',
#   '娇艳',
#   '的',
#   '花朵',
#   '作为',
#   '和亲',
#   '公主',
#   '的',
#   '皖雅',
#   '也',
#   '逃脱',
#   '不了',
#   '所谓',
#   '贡物',
#   '的',
#   '命运',
#   '绚烂',
#   '一时',
#   '的',
#   '爱情',
#   '到头来',
#   '终究',
#   '抵不上',
#   '江山',
#   '一角',
#   '爱情',
#   '如此',
#   '完美',
#   '却',
#   '又',
#   '失落',
#   '皖雅',
#   '的',
#   '结局',
#   '苦涩',
#   '却',
#   '又',
#   '实际',
#   '地',
#   '描绘',
#   '了',
#   '宫廷',
#   '女子',
#   '悲婉',
#   '的',
#   '一生',
#   '看尽',
#   '世间',
#   '无限',
#   '遗憾',
#   '只',
#   '因',
#   '爱情',
#   '如此',
#   '脆弱',
#   '三个',
#   '男人',
#   '用',
#   '不同',
#   '的',
#   '方式',
#   '爱着',
#   '这位',
#   '花神',
#   '她',
#   '本',
#   '可换种',
#   '选择',
#   '使',
#   '自己',
#   '轻松',
#   '可',
#   '她',
#   '还是',
#   '执着',
#   '于',
#   '她',
#   '的',
#   '爱',
#   '终究',
#   '她',
#   '的',
#   '爱害',
#   '了',
#   '她',
#   '爱情',
#   '总是',
#   '这么',
#   '威力',
#   '无限'],
#  ['总之',
#   '这是',
#   '一本',
#   '能',
#   '让',
#   '人',
#   '引发',
#   '起',
#   '认同感',
#   '的',
#   '也',
#   '很',
#   '有趣',
#   '很',
#   '个性',
#   '很',
#   '像',
#   '那么',
#   '一',
#   '回事',
#   '的',
#   '血型',
#   '书',
#   '或许',
#   '每个',
#   '人',
#   '的',
#   '身上',
#   '都',
#   '已',
#   '不再',
#   '只是',
#   '某',
#   '一种',
#   '血型',
#   '的',
#   '特质',
#   '而是',
#   '在',
#   '相互',
#   '的',
#   '交融',
#   '激荡',
#   '中',
#   '发生',
#   '着',
#   '嬗变',
#   '于是',
#   '型',
#   '的',
#   '人',
#   '可能',
#   '拥有',
#   '了',
#   '型',
#   '的',
#   '某种',
#   '特质',
#   '型',
#   '的',
#   '人',
#   '慢慢',
#   '也',
#   '习得',
#   '了',
#   '型',
#   '的',
#   '一些',
#   '模式',
#   '毕竟',
#   '血型',
#   '也',
#   '是',
#   '在',
#   '不断',
#   '的',
#   '进化',
#   '中型',
#   '不',
#   '就是',
#   '晚于',
#   '新近',
#   '出现',
#   '的',
#   '血型',
#   '类型',
#   '吗',
#   '到',
#   '新',
#   '血型',
#   '再',
#   '进化',
#   '出来',
#   '的',
#   '时候',
#   '我们',
#   '一定',
#   '还会',
#   '有',
#   '更',
#   '新型',
#   '的',
#   '血型',
#   '说明书'],
#  ['总',
#   '之前',
#   '两位',
#   '作者',
#   '写得',
#   '比较',
#   '好',
#   '即',
#   '年',
#   '那段',
#   '史实',
#   '之后',
#   '则',
#   '所',
#   '限于',
#   '国内',
#   '档案',
#   '不',
#   '公开',
#   '的',
#   '原因',
#   '还是',
#   '看',
#   '国外',
#   '中文',
#   '互联网',
#   '的',
#   '吧'],
#  ['总有一天',
#   '我们',
#   '会',
#   '对',
#   '流逝',
#   '的',
#   '时间',
#   '和',
#   '消失',
#   '的',
#   '往事',
#   '习以为常',
#   '无论',
#   '和',
#   '谁',
#   '以',
#   '怎样',
#   '的',
#   '方式',
#   '结束',
#   '溺水者',
#   '怎',
#   '知道',
#   '是',
#   '哪',
#   '一滴水',
#   '要',
#   '了',
#   '他',
#   '的',
#   '命',
#   '那',
#   '一天',
#   '我',
#   '二十一岁',
#   '在',
#   '我',
#   '一生',
#   '的',
#   '黄金时代',
#   '我',
#   '有',
#   '好多',
#   '奢望',
#   '我',
#   '想',
#   '爱',
#   '想',
#   '吃',
#   '还',
#   '想',
#   '在',
#   '一瞬间',
#   '变成',
#   '天上',
#   '半明半暗',
#   '的',
#   '云',
#   '千万',
#   '人',
#   '之中',
#   '遇到',
#   '你',
#   '所',
#   '遇到',
#   '的',
#   '人于',
#   '千万年',
#   '之中',
#   '时间',
#   '的',
#   '无涯',
#   '荒野',
#   '里',
#   '没有',
#   '早',
#   '一步',
#   '也',
#   '没有',
#   '晚一',
#   '不',
#   '刚巧',
#   '赶上',
#   '了'],
#  ['总体',
#   '感觉',
#   '还是',
#   '不错',
#   '的',
#   '介绍',
#   '的',
#   '比较',
#   '全面',
#   '很多',
#   '的',
#   '东西',
#   '都',
#   '是',
#   '其他',
#   '的',
#   '书籍',
#   '上学',
#   '不到',
#   '的',
#   '可惜',
#   '就是',
#   '英文',
#   '的',
#   '在',
#   '国内',
#   '关于',
#   '中文',
#   '排版',
#   '的',
#   '系统',
#   '理念',
#   '还',
#   '未',
#   '形成',
#   '至少',
#   '关于',
#   '系统',
#   '的',
#   '阐述',
#   '汉字',
#   '排版',
#   '的',
#   '书籍',
#   '不',
#   '多',
#   '就是',
#   '有',
#   '介绍',
#   '的',
#   '也',
#   '很',
#   '肤浅',
#   '我',
#   '曾经',
#   '就',
#   '搜过',
#   '多',
#   '关于',
#   '汉字',
#   '排版',
#   '的',
#   '买',
#   '过',
#   '好几本',
#   '关于',
#   '汉字',
#   '排版',
#   '的',
#   '书籍',
#   '但',
#   '很',
#   '令',
#   '我',
#   '失望',
#   '都',
#   '不怎么样',
#   '希望',
#   '以后',
#   '中国',
#   '在',
#   '这方面',
#   '多向',
#   '先进',
#   '国家',
#   '学习',
#   '完善',
#   '中文',
#   '排版',
#   '一套',
#   '理论体系'],
#  ['总是',
#   '为',
#   '浑浑噩噩',
#   '的',
#   '生活',
#   '而',
#   '苦恼',
#   '总是',
#   '因为',
#   '没有',
#   '足够',
#   '的',
#   '时间',
#   '而',
#   '无所适从',
#   '时间',
#   '管理',
#   '虽说',
#   '是',
#   '一些',
#   '老生常谈',
#   '的',
#   '技法',
#   '但是',
#   '坚持',
#   '下来',
#   '真的',
#   '很',
#   '有效',
#   '每当',
#   '下班',
#   '回家',
#   '的',
#   '时候',
#   '都',
#   '会',
#   '有',
#   '一种',
#   '满足感',
#   '是',
#   '一种',
#   '发自内心',
#   '的',
#   '充实',
#   '和',
#   '兴奋',
#   '这',
#   '本书',
#   '买',
#   '回家',
#   '就',
#   '看',
#   '完',
#   '了',
#   '再',
#   '加上',
#   '执行',
#   '过程',
#   '中',
#   '又',
#   '进行',
#   '了',
#   '温故知新',
#   '如果',
#   '你',
#   '实在',
#   '不',
#   '知道',
#   '如何',
#   '安排',
#   '自己',
#   '的',
#   '时间',
#   '买',
#   '一本',
#   '看看',
#   '还是',
#   '有',
#   '好处',
#   '的',
#   '起码',
#   '从',
#   '心里',
#   '上',
#   '你',
#   '会',
#   '有',
#   '工作',
#   '和',
#   '学习',
#   '的',
#   '欲望',
#   '因为',
#   '时间',
#   '不会',
#   '因',
#   '任何',
#   '事情',
#   '而',
#   '停止'],
#  ['总是',
#   '容易',
#   '被',
#   '别样',
#   '的',
#   '爱情',
#   '所感',
#   '隐忍',
#   '的',
#   '爱情',
#   '结局',
#   '也',
#   '是',
#   '一样',
#   '的',
#   '完美',
#   '如',
#   '斯',
#   '喜欢',
#   '这样',
#   '的',
#   '爱情',
#   '真的',
#   '不',
#   '知道',
#   '该',
#   '说些',
#   '什么',
#   '我',
#   '很',
#   '感谢',
#   '这些',
#   '写出',
#   '优秀',
#   '的',
#   '作品',
#   '让',
#   '我',
#   '感受',
#   '心痛',
#   '甜蜜',
#   '羞涩',
#   '在',
#   '现实生活',
#   '中',
#   '这样',
#   '独有',
#   '的',
#   '爱情',
#   '很难',
#   '吧',
#   '我',
#   '有时候',
#   '真的',
#   '在',
#   '做梦',
#   '可以',
#   '回到',
#   '很久以前',
#   '可以',
#   '去',
#   '爱',
#   '这样',
#   '的',
#   '男子',
#   '感受',
#   '这样',
#   '的',
#   '男子',
#   '的',
#   '心胸',
#   '气度',
#   '感受',
#   '这样',
#   '男子',
#   '的',
#   '爱恨',
#   '情仇',
#   '拥有',
#   '这样',
#   '的',
#   '爱情',
#   '这种',
#   '念头',
#   '或许',
#   '直至',
#   '死亡',
#   '也',
#   '无法',
#   '成为',
#   '现实',
#   '所以',
#   '我',
#   '沉迷于',
#   '古代',
#   '小说',
#   '无法自拔',
#   '几乎',
#   '爱恋'],
#  ['总',
#   '感觉',
#   '历史',
#   '这',
#   '东西',
#   '是',
#   '发生',
#   '在',
#   '过去',
#   '的',
#   '已经',
#   '完成',
#   '一切',
#   '都',
#   '不',
#   '可能',
#   '假设',
#   '也',
#   '无法',
#   '用',
#   '想象',
#   '去',
#   '还原',
#   '它',
#   '的',
#   '真象',
#   '所以',
#   '相对',
#   '于',
#   '历史',
#   '小说',
#   '我',
#   '更',
#   '喜欢',
#   '的',
#   '是',
#   '正史',
#   '甚或',
#   '是',
#   '野史',
#   '买',
#   '这',
#   '套书',
#   '并',
#   '看',
#   '它',
#   '是',
#   '一个',
#   '很',
#   '偶然',
#   '的',
#   '原因',
#   '因为',
#   '要',
#   '陪',
#   '领导',
#   '出趟',
#   '远',
#   '差怕',
#   '旅途',
#   '寂寞',
#   '顺手',
#   '拿',
#   '了',
#   '一本',
#   '时寒冰',
#   '的',
#   '中国',
#   '怎么办',
#   '就',
#   '上路',
#   '了',
#   '而',
#   '我',
#   '的',
#   '领导',
#   '不但',
#   '极其',
#   '喜好',
#   '读书',
#   '也',
#   '是',
#   '一个',
#   '很',
#   '有',
#   '人格魅力',
#   '的',
#   '人',
#   '却',
#   '一路',
#   '横刀夺爱',
#   '最后',
#   '把',
#   '书',
#   '还',
#   '我',
#   '的',
#   '时候',
#   '向',
#   '我',
#   '推荐',
#   '了',
#   '大',
#   '秦',
#   '帝国',
#   '一回',
#   '单位',
#   '就',
#   '赶紧',
#   '从',
#   '当当网',
#   '上',
#   '订购',
#   '了',
#   '这',
#   '套书',
#   '我',
#   '也',
#   '算是',
#   '奉命',
#   '读书',
#   '吧',
#   '历时',
#   '一个半月',
#   '总算',
#   '看',
#   '完',
#   '了',
#   '读',
#   '得',
#   '不算',
#   '细',
#   '也',
#   '不算',
#   '深',
#   '更',
#   '谈不上',
#   '透只',
#   '简单',
#   '谈',
#   '几点',
#   '感觉',
#   '吧',
#   '从',
#   '本书',
#   '的',
#   '立意',
#   '来说',
#   '正',
#   '象',
#   '作者',
#   '的',
#   '题记',
#   '是',
#   '要',
#   '献给',
#   '中国',
#   '原生',
#   '文明',
#   '的',
#   '光荣',
#   '与',
#   '梦想',
#   '他',
#   '是',
#   '这样',
#   '说',
#   '的',
#   '也',
#   '是',
#   '这样',
#   '做',
#   '的',
#   '他',
#   '毫不',
#   '吝啬',
#   '的',
#   '给予',
#   '了',
#   '那个',
#   '时代',
#   '无与伦比',
#   '的',
#   '溢美之词',
#   '我',
#   '想',
#   '在',
#   '中华文明',
#   '经历',
#   '了',
#   '夏商周',
#   '三代',
#   '的',
#   '孕育',
#   '和',
#   '发展',
#   '到',
#   '那个',
#   '时候',
#   '绽放',
#   '出',
#   '了',
#   '绚烂',
#   '的',
#   '花朵',
#   '的确',
#   '是',
#   '一个',
#   '充满',
#   '生命',
#   '张力',
#   '激情',
#   '梦想',
#   '迸射',
#   '的',
#   '大',
#   '变革时代',
#   '值得',
#   '我们',
#   '后来',
#   '之',
#   '人',
#   '永远',
#   '的',
#   '去',
#   '研究',
#   '和',
#   '挖掘',
#   '虽然',
#   '作者',
#   '对',
#   '自己',
#   '喜爱',
#   '的',
#   '人',
#   '对',
#   '自己',
#   '喜欢',
#   '的',
#   '秦',
#   '王朝',
#   '毫不掩饰',
#   '的',
#   '给予',
#   '美化',
#   '稍显',
#   '有失',
#   '偏颇',
#   '但',
#   '确实',
#   '合',
#   '了',
#   '他',
#   '本来',
#   '的',
#   '题意',
#   '也',
#   '无可厚非',
#   '从',
#   '本书',
#   '的',
#   '结构',
#   '来说',
#   '以',
#   '从孝公',
#   '商鞅',
#   '变法',
#   '起到',
#   '秦二世',
#   '亡国',
#   '这',
#   '二百余年',
#   '间',
#   '秦国',
#   '的',
#   '几个',
#   '重大',
#   '历史',
#   '片断',
#   '为',
#   '线索',
#   '着重',
#   '刻画',
#   '了',
#   '几位',
#   '明主',
#   '重臣',
#   '的',
#   '内心',
#   '性格',
#   '和',
#   '才',
#   '具',
#   '很',
#   '有',
#   '可读性',
#   '让',
#   '人',
#   '对',
#   '整个',
#   '历史',
#   '过程',
#   '一目了然',
#   '特别',
#   '是',
#   '几个',
#   '重要',
#   '历史',
#   '人物',
#   '给',
#   '人',
#   '印象',
#   '深刻',
#   '但是',
#   '在',
#   '很多',
#   '章节',
#   '铺排',
#   '上',
#   '让',
#   '人',
#   '感觉',
#   '有些',
#   '太过',
#   '松散',
#   '有些',
#   '时候',
#   '读过去',
#   '章节',
#   '之间',
#   '的',
#   '历史',
#   '年代',
#   '有所',
#   '重合',
#   '甚至',
#   '颠倒',
#   '我',
#   '都',
#   '不',
#   '知道',
#   '人',
#   '到底',
#   '是',
#   '哪个',
#   '年代',
#   '经常',
#   '的',
#   '是',
#   '人物',
#   '与',
#   '历史',
#   '对不上',
#   '号',
#   '因为',
#   '是',
#   '初读',
#   '就',
#   '不再',
#   '一一',
#   '列出',
#   '具体',
#   '所在',
#   '了',
#   '不过',
#   '这',
#   '可能',
#   '是',
#   '我',
#   '历史',
#   '知识',
#   '匮乏',
#   '也',
#   '可能',
#   '正是',
#   '历史',
#   '小说',
#   '有别于',
#   '正史',
#   '的',
#   '特征',
#   '所在',
#   '吧',
#   '要是',
#   '以后',
#   '再版',
#   '的',
#   '时候',
#   '我',
#   '希望',
#   '作者',
#   '在',
#   '整体',
#   '布局',
#   '上',
#   '能够',
#   '再',
#   '紧凑',
#   '些',
#   '在',
#   '叙事',
#   '的',
#   '顺序',
#   '上',
#   '能够',
#   '再',
#   '简明',
#   '一些',
#   '从',
#   '本书',
#   '的',
#   '内容',
#   '来说',
#   '这部',
#   '小说',
#   '真的',
#   '可以',
#   '当作',
#   '一部',
#   '普及',
#   '历史',
#   '知识',
#   '的',
#   '好书',
#   '来读',
#   '作者',
#   '的',
#   '原意',
#   '是',
#   '想',
#   '尽力',
#   '给',
#   '我们',
#   '还原',
#   '历史',
#   '的',
#   '原貌',
#   '以',
#   '作者',
#   '渊博',
#   '的',
#   '知识',
#   '优美',
#   '的',
#   '笔触',
#   '也',
#   '的确',
#   '做到',
#   '了',
#   '书',
#   '中',
#   '对',
#   '先秦',
#   '诸家',
#   '的',
#   '主张',
#   '各国',
#   '风俗',
#   '的',
#   '异同',
#   '甚至',
#   '是',
#   '打造',
#   '兵器',
#   '排兵',
#   '布阵',
#   '都',
#   '给予',
#   '了',
#   '细致入微',
#   '的',
#   '描写',
#   '让',
#   '我',
#   '对',
#   '那个',
#   '时代',
#   '有',
#   '了',
#   '更为',
#   '深刻',
#   '的',
#   '认识',
#   '对',
#   '我们',
#   '先祖',
#   '的',
#   '聪明才智',
#   '感到',
#   '无比',
#   '自豪',
#   '原来',
#   '我',
#   '看',
#   '英雄',
#   '很为',
#   '里面',
#   '的',
#   '庞大',
#   '壮观',
#   '的',
#   '箭',
#   '雨',
#   '阵势',
#   '不解',
#   '以为',
#   '那',
#   '是',
#   '老谋子',
#   '故意',
#   '制造',
#   '出来',
#   '的',
#   '视觉效果',
#   '现在',
#   '看来',
#   '我们',
#   '先祖',
#   '的确',
#   '曾',
#   '有',
#   '那样',
#   '的',
#   '辉煌',
#   '阵容',
#   '与',
#   '古罗马',
#   '的',
#   '重装',
#   '骑兵',
#   '方阵',
#   '相比',
#   '毫不逊色',
#   '但',
#   '最',
#   '开始',
#   '的',
#   '那些',
#   '武侠小说',
#   '一样',
#   '的',
#   '情节',
#   '可能',
#   '很',
#   '符合',
#   '当时',
#   '那个',
#   '崇侠',
#   '尚武',
#   '的',
#   '时代',
#   '但',
#   '还是',
#   '过于',
#   '夸张',
#   '了',
#   '若',
#   '能',
#   '再',
#   '改动',
#   '一下',
#   '无疑',
#   '会',
#   '这部',
#   '小说',
#   '更显',
#   '厚重',
#   '从',
#   '本书',
#   '的',
#   '语言',
#   '来说',
#   '作者',
#   '的',
#   '文化',
#   '功底',
#   '深厚',
#   '对',
#   '语言',
#   '的',
#   '驾驭能力',
#   '达到',
#   '了',
#   '炉火纯青',
#   '的',
#   '地步',
#   '对',
#   '情节',
#   '的',
#   '展开',
#   '跌宕起伏',
#   '有张有弛',
#   '对',
#   '场景',
#   '的',
#   '描写',
#   '凛然',
#   '生动',
#   '身临其境',
#   '对',
#   '人物',
#   '的',
#   '刻画',
#   '形象',
#   '逼真',
#   '真切感',
#   '人',
#   '但',
#   '也',
#   '不是',
#   '没有',
#   '没有',
#   '败笔',
#   '对',
#   '很多',
#   '历史背景',
#   '的',
#   '交待',
#   '作者',
#   '显然',
#   '是',
#   '怕',
#   '读者',
#   '遗忘',
#   '而',
#   '不厌其烦',
#   '的',
#   '数次',
#   '交待',
#   '因而',
#   '显得',
#   '啰',
#   '里',
#   '啰嗦',
#   '让',
#   '一些',
#   '颇',
#   '有',
#   '隐喻',
#   '色彩',
#   '的',
#   '章节',
#   '和',
#   '片段',
#   '也',
#   '变得',
#   '索然无味',
#   '了',
#   '瑕不掩瑜',
#   '无论',
#   '怎么',
#   '说',
#   '这',
#   '都',
#   '是',
#   '一部',
#   '很',
#   '好',
#   '的',
#   '历史',
#   '小说',
#   '是',
#   '作者',
#   '浸淫',
#   '十几年',
#   '光阴',
#   '而',
#   '凝结',
#   '的',
#   '心血',
#   '的',
#   '结晶',
#   '我',
#   '也',
#   '希望',
#   '作者',
#   '能',
#   '在',
#   '以后',
#   '的',
#   '修订',
#   '中',
#   '不断',
#   '修改',
#   '完善',
#   '让',
#   '这部',
#   '小说',
#   '成为',
#   '传世',
#   '名作',
#   '让',
#   '中华民族',
#   '的',
#   '原生',
#   '文明',
#   '再次',
#   '大',
# ...
#   '紧凑',
#   '吧',
#   '起码',
#   '很',
#   '厚实',
#   '里面',
#   '的',
#   '内容',
#   '很',
#   '详细',
#   '对',
#   '即将',
#   '或者',
#   '刚刚',
#   '为',
#   '人',
#   '父母',
#   '的',
#   '人',
#   '来说',
#   '比较',
#   '有',
#   '指导意义',
#   '但是',
#   '如果',
#   '事前',
#   '看过',
#   '一些',
#   '甚至',
#   '是',
#   '很多',
#   '此类',
#   '书籍',
#   '不',
#   '知道',
#   '她',
#   '的',
#   '作用',
#   '会',
#   '不会',
#   '打',
#   '一些',
#   '折扣',
#   '书中',
#   '的',
#   '文字',
#   '言简意赅',
#   '在',
#   '照顾',
#   '孩子',
#   '的',
#   '同时',
#   '也',
#   '有',
#   '精力',
#   '去',
#   '看',
#   '而且',
#   '建议',
#   '全面',
#   '还有',
#   '一些',
#   '新生儿',
#   '的',
#   '特点',
#   '以',
#   '孩子',
#   '的',
#   '口吻',
#   '说出',
#   '很',
#   '有意思',
#   '正在',
#   '阅读',
#   '中'],
#  ['收到',
#   '这',
#   '本书',
#   '后',
#   '又',
#   '一鼓作气',
#   '的',
#   '看',
#   '了',
#   '一遍',
#   '现在',
#   '放在',
#   '床头',
#   '时不时',
#   '还会',
#   '在',
#   '翻阅',
#   '几页',
#   '里面',
#   '的',
#   '每个',
#   '小',
#   '情节',
#   '都',
#   '会',
#   '给',
#   '自己',
#   '带来',
#   '好',
#   '心情'],
#  ['收到',
#   '这',
#   '本书',
#   '后用',
#   '了',
#   '一个',
#   '星期',
#   '把',
#   '这',
#   '本书',
#   '看',
#   '了',
#   '一遍',
#   '感觉',
#   '这是',
#   '一本',
#   '介绍',
#   '搜索引擎',
#   '入门',
#   '很',
#   '好',
#   '的',
#   '书',
#   '不过',
#   '还是',
#   '偏向',
#   '于',
#   '理论',
#   '看',
#   '完',
#   '这',
#   '本书',
#   '后',
#   '感觉',
#   '对',
#   '搜索引擎',
#   '的',
#   '结构',
#   '有',
#   '了',
#   '一个',
#   '大概',
#   '的',
#   '了解',
#   '当然',
#   '还是',
#   '比较',
#   '初步',
#   '的',
#   '不过',
#   '正如',
#   '许多',
#   '网友',
#   '所说',
#   '的',
#   '那样',
#   '这',
#   '本书',
#   '的',
#   '排版',
#   '可能',
#   '是',
#   '最',
#   '有',
#   '争议',
#   '的',
#   '地方',
#   '了',
#   '个人感觉',
#   '这',
#   '本书',
#   '空白',
#   '的',
#   '地方',
#   '太大太多',
#   '了',
#   '完全',
#   '可以',
#   '更加',
#   '紧凑',
#   '一些',
#   '但是',
#   '这',
#   '并',
#   '不',
#   '影响',
#   '它',
#   '是',
#   '一本',
#   '了解',
#   '搜索引擎',
#   '的',
#   '好书'],
#  ['收到',
#   '这',
#   '本书',
#   '后',
#   '虽然',
#   '一个',
#   '人',
#   '看着',
#   '宝宝',
#   '几乎',
#   '没有',
#   '时间',
#   '但',
#   '我',
#   '还是',
#   '挤出',
#   '了',
#   '所有',
#   '的',
#   '时间',
#   '在',
#   '二天',
#   '内',
#   '看',
#   '完',
#   '了',
#   '这',
#   '真的',
#   '是',
#   '至今',
#   '为止',
#   '看到',
#   '过',
#   '的',
#   '最好',
#   '的',
#   '一本',
#   '育儿',
#   '书',
#   '让',
#   '我',
#   '在',
#   '教育',
#   '儿子',
#   '的',
#   '路上',
#   '有',
#   '了',
#   '指',
#   '路灯',
#   '审视',
#   '自己',
#   '平时',
#   '的',
#   '一些',
#   '习惯',
#   '发现',
#   '文中',
#   '提到',
#   '几处',
#   '也',
#   '知道',
#   '了',
#   '妈妈',
#   '的',
#   '一个',
#   '小',
#   '细节',
#   '几乎',
#   '会',
#   '影响',
#   '宝宝',
#   '的',
#   '一生',
#   '真的',
#   '感谢',
#   '作家',
#   '有',
#   '这样',
#   '的',
#   '一本',
#   '好书',
#   '问世',
#   '也',
#   '真的',
#   '庆幸',
#   '自己',
#   '在',
#   '儿子',
#   '一岁',
#   '时',
#   '就',
#   '看到',
#   '了',
#   '这',
#   '本书',
#   '好',
#   '在',
#   '一切',
#   '都',
#   '来得',
#   '急',
#   '改正'],
#  ['收到',
#   '以后',
#   '大致',
#   '翻看',
#   '了',
#   '一下',
#   '目前',
#   '只学到',
#   '第二章',
#   '感觉',
#   '非常',
#   '不错',
#   '内容',
#   '翔实',
#   '架构',
#   '也',
#   '不错',
#   '有',
#   '考情',
#   '分析',
#   '主要',
#   '考点',
#   '知识',
#   '框架',
#   '考题',
#   '解析',
#   '同步',
#   '训练',
#   '及',
#   '答案',
#   '解析',
#   '等',
#   '对于',
#   '我',
#   '这种',
#   '主要',
#   '靠',
#   '自学',
#   '的',
#   '人',
#   '来讲',
#   '可以',
#   '帮助',
#   '我',
#   '更好',
#   '的',
#   '理解',
#   '教材内容',
#   '起到',
#   '事半功倍',
#   '的',
#   '效果',
#   '有点',
#   '美中不足',
#   '的',
#   '地方',
#   '就是',
#   '印刷',
#   '的',
#   '字体',
#   '稍微',
#   '小',
#   '了',
#   '一点',
#   '看起来',
#   '有些',
#   '费力',
#   '大概',
#   '是',
#   '为了',
#   '给',
#   '大家',
#   '节省',
#   '购买',
#   '成本',
#   '的',
#   '缘故',
#   '吧',
#   '可惜',
#   '我',
#   '宁愿',
#   '花高',
#   '一点',
#   '的',
#   '代价',
#   '来',
#   '换回',
#   '更',
#   '舒服',
#   '的',
#   '阅读'],
#  ['收到',
#   '书',
#   '了',
#   '封面',
#   '好',
#   '啊',
#   '而且',
#   '好',
#   '有',
#   '质感',
#   '哦',
#   '喜欢',
#   '得',
#   '不得了',
#   '一口气',
#   '读完',
#   '这本',
#   '书写',
#   '的',
#   '很',
#   '不错',
#   '呵呵',
#   '喜欢',
#   '苏',
#   '小鱼',
#   '和',
#   '陈苏雷',
#   '也',
#   '喜欢',
#   '那首',
#   '亲爱',
#   '的',
#   '小鱼',
#   '的',
#   '诗',
#   '故事',
#   '中',
#   '的',
#   '男主角',
#   '无论',
#   '职业',
#   '和',
#   '生活',
#   '背景',
#   '都',
#   '很',
#   '像',
#   '电影',
#   '风月',
#   '俏佳人',
#   '中',
#   '的',
#   '男主角',
#   '我',
#   '看过',
#   '作者',
#   '的',
#   '的',
#   '女王',
#   '进化论',
#   '逃爱记',
#   '钱',
#   '多多',
#   '嫁人',
#   '记都',
#   '不错呀',
#   '一个',
#   '男人',
#   '和',
#   '他',
#   '的',
#   '一张',
#   '卡',
#   '不是',
#   '女人',
#   '想要',
#   '的',
#   '全部',
#   '说',
#   '得',
#   '太好了',
#   '女人',
#   '要是',
#   '自主',
#   '自立',
#   '还',
#   '怕',
#   '什么',
#   '金融风暴',
#   '呀'],
#  ['收到',
#   '书后',
#   '发现',
#   '书',
#   '虽然',
#   '只有',
#   '页',
#   '但',
#   '字',
#   '比',
#   '黄金',
#   '游戏',
#   '一要',
#   '小且',
#   '紧凑',
#   '因此',
#   '字数',
#   '实际上',
#   '多',
#   '很多',
#   '内容',
#   '也',
#   '更',
#   '丰富',
#   '其',
#   '质量',
#   '远非',
#   '那些',
#   '快餐',
#   '式',
#   '书籍',
#   '可比',
#   '强烈推荐',
#   '很',
#   '敬佩',
#   '豪哥',
#   '的',
#   '为',
#   '人',
#   '在',
#   '每日',
#   '的',
#   '博客',
#   '里',
#   '无私',
#   '和',
#   '大家',
#   '分享',
#   '在',
#   '这里',
#   '真诚',
#   '跟',
#   '豪哥',
#   '到',
#   '声谢'],
#  ['收到',
#   '书',
#   '还',
#   '未',
#   '打开',
#   '就',
#   '被',
#   '封面',
#   '的',
#   '鲜艳',
#   '色彩',
#   '及版样',
#   '吸引',
#   '迫不急待',
#   '的',
#   '打开',
#   '书内',
#   '的',
#   '设计',
#   '及',
#   '彩图',
#   '也',
#   '不错',
#   '色泽',
#   '及',
#   '印刷',
#   '质量',
#   '都',
#   '称',
#   '的',
#   '上',
#   '好',
#   '没有',
#   '味道',
#   '贴图',
#   '也',
#   '从简',
#   '入深',
#   '价格',
#   '也',
#   '不贵',
#   '拿',
#   '回家',
#   '小宝贝',
#   '也',
#   '很',
#   '喜欢',
#   '我家',
#   '宝宝',
#   '只有',
#   '岁',
#   '个',
#   '月',
#   '对于',
#   '她',
#   '贴片',
#   '不太好',
#   '撕大',
#   '一些',
#   '的',
#   '贴片',
#   '要',
#   '我',
#   '来',
#   '帮',
#   '她',
#   '撕',
#   '不过',
#   '今天',
#   '再玩时',
#   '已经',
#   '比',
#   '昨天',
#   '撕',
#   '的',
#   '好',
#   '很多',
#   '了',
#   '可以',
#   '锻炼',
#   '她',
#   '的',
#   '小手',
#   '呢',
#   '等',
#   '这',
#   '几本',
#   '用',
#   '完',
#   '了',
#   '我',
#   '想',
#   '我',
#   '还',
#   '会',
#   '再',
#   '给',
#   '她',
#   '买',
#   '一些',
#   '类似',
#   '的',
#   '书'],
#  ['收到',
#   '了',
#   '送货',
#   '的',
#   '速度',
#   '还是',
#   '没得说的',
#   '呀',
#   '比',
#   '想象',
#   '中',
#   '的',
#   '好',
#   '很多',
#   '哦',
#   '随书',
#   '还',
#   '赠送',
#   '了',
#   '速查',
#   '的',
#   '挂图',
#   '方便',
#   '及时',
#   '查找',
#   '每种',
#   '病',
#   '编写',
#   '都',
#   '有',
#   '这',
#   '几',
#   '部分',
#   '组成',
#   '症状',
#   '表现',
#   '产生',
#   '原因',
#   '并发症',
#   '易发',
#   '人群',
#   '应对',
#   '方法',
#   '家庭',
#   '护理',
#   '对于',
#   '年轻',
#   '父母',
#   '来说',
#   '介绍',
#   '了',
#   '一些',
#   '基础',
#   '医护',
#   '知识'],
#  ['收到',
#   '本书',
#   '完好',
#   '快递',
#   '不快',
#   '一周',
#   '时间',
#   '你',
#   '喜欢',
#   '的',
#   '人',
#   '在',
#   '哪里',
#   '哪里',
#   '最',
#   '可爱',
#   '购买',
#   '本书',
#   '的',
#   '原因',
#   '我嘘',
#   '这个',
#   '故事',
#   '的',
#   '主线',
#   '是',
#   '财产',
#   '分配',
#   '来',
#   '的',
#   '子女',
#   '因',
#   '父母',
#   '的',
#   '财产',
#   '分配',
#   '而',
#   '聚到',
#   '一起',
#   '最后',
#   '各取所需',
#   '各奔东西',
#   '没想到',
#   '这才',
#   '是',
#   '故事',
#   '的',
#   '主要',
#   '内容',
#   '故事',
#   '结束',
#   '孑然一身',
#   '继续',
#   '往前走',
#   '继续',
#   '发生',
#   '新',
#   '的',
#   '故事',
#   '让',
#   '我',
#   '想起',
#   '在',
#   '大学校园',
#   '阶梯教室',
#   '看书',
#   '的',
#   '日子',
#   '一个',
#   '人',
#   '静静的',
#   '饿',
#   '了',
#   '大饼',
#   '充饥',
#   '喝',
#   '凉开水'],
#  ['收到',
#   '本书',
#   '非常',
#   '兴奋',
#   '带',
#   '着',
#   '梦想',
#   '与',
#   '期望',
#   '迫不及待',
#   '的',
#   '打开',
#   '包装',
#   '开始',
#   '阅读',
#   '觉得',
#   '书中',
#   '各',
#   '部分',
#   '都',
#   '是',
#   '不错',
#   '的',
#   '但是',
#   '缺少',
#   '发动机',
#   '和',
#   '航电',
#   '系统',
#   '是',
#   '美中不足',
#   '的',
#   '事情',
#   '另外',
#   '就是',
#   '其中',
#   '的',
#   '现有',
#   '工业',
#   '范例',
#   '太',
#   '少',
#   '很多',
#   '新型',
#   '结构',
#   '都',
#   '没有',
#   '展现',
#   '或者',
#   '提示',
#   '也许',
#   '是',
#   '我们',
#   '的',
#   '技术',
#   '封锁',
#   '太久',
#   '太久',
#   '了',
#   '不过',
#   '黑鹰',
#   '直升机',
#   '也',
#   '是',
#   '一块',
#   '很',
#   '经典',
#   '的',
#   '机型',
#   '如果',
#   '能',
#   '好好',
#   '解剖',
#   '这',
#   '款',
#   '机子',
#   '对',
#   '我们',
#   '发展',
#   '民用',
#   '直升机',
#   '是',
#   '有',
#   '相当',
#   '大',
#   '的',
#   '帮助',
#   '的'],
#  ['逝去',
#   '亲人',
#   '的',
#   '痛',
#   '也许',
#   '只有',
#   '当事人',
#   '才能',
#   '真切',
#   '地',
#   '感受',
#   '这',
#   '本书',
#   '讲述',
#   '的',
#   '是',
#   '梅姨',
#   '逝去',
#   '后',
#   '她',
#   '的',
#   '亲人',
#   '对',
#   '她',
#   '的',
#   '思念',
#   '梅姨',
#   '生前',
#   '和',
#   '她',
#   '的',
#   '老伴',
#   '收养',
#   '了',
#   '一个',
#   '孤苦伶仃',
#   '的',
#   '小女孩',
#   '两个',
#   '老人',
#   '自己',
#   '并',
#   '不',
#   '富裕',
#   '甚至',
#   '可说是',
#   '生活',
#   '拮据',
#   '但',
#   '他们',
#   '以',
#   '自己',
#   '全部',
#   '的',
#   '爱',
#   '给',
#   '了',
#   '这个',
#   '女孩',
#   '家',
#   '的',
#   '温暖',
#   '竭尽所能',
#   '毫无保留',
#   '地',
#   '给',
#   '她',
#   '关心',
#   '和',
#   '照顾',
#   '人生',
#   '还有',
#   '什么',
#   '比',
#   '这样',
#   '无私',
#   '的',
#   '大爱',
#   '更',
#   '珍贵',
#   '的',
#   '呢',
#   '不是',
#   '亲生',
#   '胜似',
#   '亲生',
#   '这样',
#   '的',
#   '人',
#   '虽',
#   '已',
#   '逝去',
#   '却',
#   '永远',
#   '活在',
#   '别人',
#   '的',
#   '心里',
#   '让',
#   '人',
#   '很',
#   '感动',
#   '的',
#   '一本',
#   '小',
#   '书'],
#  ['适逢',
#   '刘斌',
#   '与',
#   '浩',
#   '二',
#   '的',
#   '纷争',
#   '多',
#   '说',
#   '两句',
#   '感觉',
#   '对于',
#   '普通',
#   '老百姓',
#   '来说',
#   '其实',
#   '没有',
#   '那么',
#   '多',
#   '恩怨',
#   '的',
#   '但',
#   '到',
#   '了',
#   '关键时刻',
#   '比如',
#   '战争',
#   '来临',
#   '人民',
#   '都',
#   '会',
#   '被',
#   '国家机器',
#   '所',
#   '绑架',
#   '不由自主',
#   '的',
#   '卷入纠纷',
#   '单纯',
#   '的',
#   '民族主义',
#   '无法',
#   '解决问题',
#   '当然',
#   '也',
#   '不是',
#   '放弃',
#   '原则',
#   '无条件',
#   '的',
#   '迁就',
#   '妥协',
#   '提高',
#   '国力',
#   '加深',
#   '理解',
#   '是',
#   '化解',
#   '恩怨',
#   '的',
#   '可行',
#   '办法',
#   '吧'],
#  ['是',
#   '最',
#   '值得',
#   '推荐',
#   '的',
#   '一本',
#   '科学',
#   '育儿',
#   '书',
#   '这',
#   '本书',
#   '文字',
#   '简练',
#   '有力',
#   '案例',
#   '丰富',
#   '虽然',
#   '都',
#   '是',
#   '外国',
#   '孩子',
#   '的',
#   '案例',
#   '读过',
#   '以及',
#   '实践',
#   '过后',
#   '我',
#   '发现',
#   '天下',
#   '孩子',
#   '和',
#   '天下父母',
#   '有',
#   '很多',
#   '相似之处',
#   '这',
#   '本书',
#   '我',
#   '百看不厌',
#   '每次',
#   '碰到困难',
#   '的',
#   '时候',
#   '都',
#   '能',
#   '从中',
#   '得到',
#   '启发',
#   '相信',
#   '每个',
#   '爱',
#   '孩子',
#   '的',
#   '父母',
#   '都',
#   '能',
#   '从中',
#   '获益',
#   '我',
#   '还',
#   '买',
#   '了',
#   '一些',
#   '送给',
#   '当',
#   '父母',
#   '的',
#   '朋友',
#   '我',
#   '觉得',
#   '这是',
#   '最好',
#   '的',
#   '礼物',
#   '知识',
#   '就是',
#   '力量',
#   '象书中',
#   '所说',
#   '的',
#   '养育',
#   '孩子',
#   '光有',
#   '爱',
#   '还',
#   '不够',
#   '你',
#   '还',
#   '得',
#   '有',
#   '知识',
#   '有',
#   '力量',
#   '这样',
#   '父母',
#   '和',
#   '孩子',
#   '都',
#   '能',
#   '共同',
#   '成长'],
#  ['是',
#   '长大',
#   '以后',
#   '才',
#   '读',
#   '的',
#   '这',
#   '本书',
#   '喜欢',
#   '作者',
#   '笔下',
#   '看似',
#   '无厘头',
#   '却',
#   '充满',
#   '智慧',
#   '的',
#   '皮皮',
#   '读',
#   '到',
#   '皮皮',
#   '的',
#   '朋友',
#   '杜米',
#   '和',
#   '阿尼卡',
#   '在',
#   '皮皮',
#   '离开',
#   '去',
#   '航海',
#   '的',
#   '那',
#   '一段',
#   '撕心裂肺',
#   '的',
#   '伤心',
#   '竟然',
#   '忍不住',
#   '掉',
#   '了',
#   '眼泪',
#   '然后',
#   '看到',
#   '皮皮',
#   '不能',
#   '忍受',
#   '有人',
#   '为',
#   '她',
#   '那么',
#   '伤心',
#   '而',
#   '毅然决定',
#   '留在',
#   '朋友',
#   '身边',
#   '的',
#   '时候',
#   '我',
#   '想',
#   '我',
#   '也',
#   '像',
#   '杜米',
#   '和',
#   '阿尼卡',
#   '一样',
#   '雀跃',
#   '最让人',
#   '欣慰',
#   '的',
#   '当然',
#   '是',
#   '皮皮',
#   '总有',
#   '花',
#   '不',
#   '完',
#   '的',
#   '金币',
#   '和',
#   '用不完',
#   '的',
#   '力气',
#   '林格伦',
#   '就是',
#   '有',
#   '这种',
#   '本事',
#   '让',
#   '你',
#   '笑',
#   '着',
#   '流泪',
#   '还',
#   '不得不',
#   '承认',
#   '自己',
#   '仍然',
#   '像',
#   '一个',
#   '小孩'],
#  ['是',
#   '在',
#   '同学',
#   '的',
#   '怂恿',
#   '下',
#   '买',
#   '的',
#   '所以',
#   '一买',
#   '就',
#   '买',
#   '了',
#   '两套',
#   '极',
#   '殷切',
#   '的',
#   '等到',
#   '书',
#   '她',
#   '就',
#   '迫不及待',
#   '的',
#   '开始',
#   '看',
#   '了',
#   '丢开',
#   '了',
#   '玩',
#   '得',
#   '正到',
#   '紧要关头',
#   '的',
#   '网游',
#   '和',
#   '电视剧',
#   '等',
#   '我',
#   '开始',
#   '看',
#   '的',
#   '时候',
#   '才',
#   '终于',
#   '理解',
#   '她',
#   '了',
#   '确实',
#   '是',
#   '很',
#   '不错',
#   '的',
#   '啊',
#   '第二部',
#   '的',
#   '风格',
#   '和',
#   '第一部',
#   '有',
#   '一点',
#   '不同',
#   '语言文字',
#   '的',
#   '表达',
#   '也',
#   '略有',
#   '差异',
#   '不过',
#   '整体',
#   '来说',
#   '还是',
#   '很',
#   '好看',
#   '也',
#   '是',
#   '我',
#   '拿到',
#   '的',
#   '已经',
#   '是',
#   '第四次',
#   '印刷',
#   '的',
#   '版本',
#   '了',
#   '从',
#   '很',
#   '专业',
#   '的',
#   '角度看',
#   '就',
#   '这种',
#   '速度',
#   '来说',
#   '这',
#   '本书',
#   '很',
#   '畅销',
#   '很',
#   '好'],
#  ['是',
#   '在',
#   '上',
#   '中专',
#   '时',
#   '听',
#   '同学',
#   '介绍',
#   '了',
#   '这',
#   '本书',
#   '的',
#   '具体',
#   '情节',
#   '当时',
#   '就',
#   '很',
#   '为',
#   '它',
#   '感动',
#   '而且',
#   '是',
#   '我',
#   '心仪',
#   '的',
#   '女孩',
#   '讲',
#   '给',
#   '我',
#   '听',
#   '的',
#   '于是',
#   '借',
#   '到',
#   '此书',
#   '后',
#   '就',
#   '如饥似渴',
#   '地读',
#   '了',
#   '起来',
#   '一口气',
#   '看',
#   '完',
#   '了',
#   '它',
#   '真得',
#   '是',
#   '凄婉',
#   '动人',
#   '深有',
#   '红楼',
#   '之',
#   '韵味',
#   '此后',
#   '就',
#   '始终',
#   '怀着',
#   '拥有',
#   '此书',
#   '的',
#   '强烈',
#   '愿望',
#   '遇到',
#   '一些',
#   '版本',
#   '装帧',
#   '质量',
#   '等',
#   '总令己',
#   '不',
#   '太',
#   '满意',
#   '现在',
#   '幸有',
#   '此',
#   '版本',
#   '不唯',
#   '精装',
#   '印刷',
#   '装帧',
#   '都',
#   '没得',
#   '挑且',
#   '价格',
#   '又',
#   '便宜',
#   '还',
#   '等',
#   '什么',
#   '现捧书',
#   '在手',
#   '抚玩',
#   '不已',
#   '激动',
#   '之情',
#   '难以',
#   '表达'],
#  ['是因为',
#   '我们',
#   '城市',
#   '的',
#   '读书',
#   '月',
#   '推荐',
#   '了',
#   '这',
#   '本书',
#   '才',
#   '关注',
#   '的',
#   '书',
#   '的',
#   '质量',
#   '非常',
#   '好',
#   '很',
#   '精美',
#   '当然',
#   '优惠',
#   '也',
#   '很少',
#   '我先',
#   '翻看',
#   '了',
#   '一下',
#   '发现',
#   '我',
#   '小时候',
#   '就',
#   '看过',
#   '这',
#   '本书',
#   '改编',
#   '的',
#   '连环画',
#   '好像',
#   '叫巴',
#   '学园',
#   '当时',
#   '没有',
#   '特别',
#   '喜欢',
#   '倒',
#   '有点儿',
#   '感觉',
#   '作者',
#   '在',
#   '编造',
#   '故事',
#   '的',
#   '感觉',
#   '但',
#   '这本',
#   '小说',
#   '我',
#   '女儿',
#   '非常',
#   '喜欢',
#   '每天',
#   '都',
#   '会',
#   '认真',
#   '阅读',
#   '还',
#   '非',
#   '把',
#   '她',
#   '认为',
#   '有趣',
#   '的',
#   '段落',
#   '讲',
#   '给',
#   '我',
#   '听',
#   '值得',
#   '购买',
#   '另外',
#   '这',
#   '本书',
#   '小孩',
#   '看热闹',
#   '大人',
#   '看',
#   '门道',
#   '都',
#   '会',
#   '有',
#   '收获'],
#  ['是因为',
#   '陈丹青',
#   '在',
#   '谈',
#   '鲁迅',
#   '时',
#   '的',
#   '推荐',
#   '才',
#   '留意',
#   '这',
#   '本书',
#   '并',
#   '找',
#   '来看',
#   '的',
#   '确实',
#   '很',
#   '生动有趣',
#   '应该',
#   '感谢',
#   '胡颂平',
#   '先生',
#   '尽管',
#   '他',
#   '很',
#   '谦逊',
#   '为',
#   '后人',
#   '记录',
#   '了',
#   '这些',
#   '精彩',
#   '的',
#   '片段',
#   '在',
#   '大师',
#   '人生',
#   '的',
#   '最后',
#   '几年',
#   '过',
#   '他',
#   '的',
#   '记录',
#   '才',
#   '感觉',
#   '到',
#   '原来',
#   '胡适',
#   '并',
#   '不',
#   '只是',
#   '一个',
#   '高高在上',
#   '后人',
#   '激赏',
#   '抑或',
#   '针砭',
#   '的',
#   '名人',
#   '而是',
#   '真真切切',
#   '的',
#   '离',
#   '我们',
#   '很近',
#   '很',
#   '近',
#   '的',
#   '一位',
#   '智者',
#   '一位',
#   '有血有肉',
#   '的',
#   '大师'],
#  ['是',
#   '一个',
#   '入门',
#   '的',
#   '方法',
#   '作者',
#   '通过',
#   '一定',
#   '的',
#   '特别',
#   '是',
#   '资金',
#   '管理',
#   '的',
#   '方法',
#   '强制',
#   '自我',
#   '操作',
#   '纪律',
#   '从而',
#   '克服',
#   '人性',
#   '的',
#   '弱点',
#   '把',
#   '交易',
#   '进行',
#   '记住',
#   '是',
#   '长期',
#   '进行',
#   '下去',
#   '我',
#   '认为',
#   '是',
#   '必要',
#   '的',
#   '方法',
#   '也',
#   '是',
#   '有',
#   '效果',
#   '的',
#   '对于',
#   '资金',
#   '的',
#   '管理',
#   '书中',
#   '对',
#   '一些',
#   '买卖',
#   '点',
#   '没有',
#   '说明',
#   '的',
#   '很',
#   '系统',
#   '但是',
#   '可以',
#   '说',
#   '是',
#   '领',
#   '大家',
#   '入门',
#   '而已',
#   '特别',
#   '第一',
#   '部分',
#   '的',
#   '内容',
#   '是',
#   '市场',
#   '参与',
#   '必须',
#   '的',
#   '基本知识',
#   '买卖',
#   '的',
#   '系统',
#   '还要',
#   '靠',
#   '大家',
#   '慢慢',
#   '探索',
#   '提高',
#   '进场',
#   '的',
#   '胜算',
#   '几率',
#   '回到',
#   '问题',
#   '的',
#   '实质',
#   '提出',
#   '资金',
#   '的',
#   '管理',
#   '是',
#   '重要',
#   '的'],
#  ['是',
#   '一个',
#   '朋友',
#   '送给',
#   '我',
#   '的',
#   '如今',
#   '我',
#   '又',
#   '在',
#   '把',
#   '它',
#   '推荐',
#   '给',
#   '其他',
#   '朋友',
#   '是',
#   '它',
#   '为',
#   '我',
#   '打开',
#   '了',
#   '一扇门',
#   '通向',
#   '图画书',
#   '的',
#   '宫殿',
#   '的',
#   '门',
#   '就',
#   '连',
#   '我',
#   '这个',
#   '所谓',
#   '的',
#   '教育工作者',
#   '也',
#   '要',
#   '感叹',
#   '自己',
#   '的',
#   '无知',
#   '感谢',
#   '作者',
#   '告诉',
#   '了',
#   '我们',
#   '世界',
#   '上',
#   '有',
#   '这么',
#   '多',
#   '的',
#   '好',
#   '的',
#   '图画书',
#   '我',
#   '给晓晓买',
#   '的',
#   '图画书',
#   '都',
#   '是',
#   '这样',
#   '按图索骥',
#   '买来',
#   '的',
#   '本本',
#   '都',
#   '让',
#   '她',
#   '爱不释手',
#   '当然',
#   '了',
#   '现在',
#   '还',
#   '发现',
#   '了',
#   '它',
#   '另外',
#   '一个',
#   '妙用',
#   '省钱',
#   '哈哈',
#   '试想',
#   '把',
#   '那',
#   '里面',
#   '的',
#   '书',
#   '都',
#   '买下来',
#   '要',
#   '多少',
#   '钱',
#   '啊',
#   '嘿嘿',
#   '我',
#   '不',
#   '做',
#   '傻瓜',
#   '就',
#   '这样',
#   '讲故事',
#   '也',
#   '不错'],
#  ['是',
#   '一本',
#   '我',
#   '和',
#   '女儿',
#   '共享',
#   '的',
#   '小书',
#   '内容',
#   '是',
#   '原版',
#   '的',
#   '精缩',
#   '但是',
#   '完整',
#   '且',
#   '有趣',
#   '女儿',
#   '还',
#   '小',
#   '如果',
#   '只是',
#   '读',
#   '文字',
#   '她',
#   '还',
#   '不',
#   '明白',
#   '其中',
#   '的',
#   '含义',
#   '并且',
#   '容易',
#   '开小差',
#   '呢',
#   '所以',
#   '这',
#   '本书',
#   '的',
#   '优点',
#   '在于',
#   '有',
#   '大量',
#   '的',
#   '插图',
#   '可以',
#   '利用',
#   '插图',
#   '给',
#   '宝宝',
#   '讲述',
#   '效果',
#   '不错',
#   '呢',
#   '只是',
#   '用',
#   '了',
#   '元',
#   '多',
#   '钱',
#   '就',
#   '可以',
#   '享受',
#   '美妙',
#   '的',
#   '故事',
#   '和',
#   '亲子',
#   '的',
#   '时刻',
#   '是不是',
#   '物超所值',
#   '呢',
#   '我',
#   '和',
#   '女儿',
#   '都',
#   '是',
#   '忠实',
#   '书迷',
#   '这套',
#   '的',
#   '其他',
#   '图书',
#   '也',
#   '统统',
#   '买下',
#   '闲',
#   '了',
#   '细读',
#   '其乐融融'],
#  ['是',
#   '一本',
#   '我',
#   '和',
#   '女儿',
#   '共享',
#   '的',
#   '小书',
#   '内容',
#   '是',
#   '原版',
#   '的',
#   '精缩',
#   '但是',
#   '完整',
#   '且',
#   '有趣',
#   '女儿',
#   '还',
#   '小',
#   '如果',
#   '只是',
#   '读',
#   '文字',
#   '她',
#   '还',
#   '不',
#   '明白',
#   '其中',
#   '的',
#   '含义',
#   '并且',
#   '容易',
#   '开小差',
#   '呢',
#   '所以',
#   '这',
#   '本书',
#   '的',
#   '优点',
#   '在于',
#   '有',
#   '大量',
#   '的',
#   '插图',
#   '可以',
#   '利用',
#   '插图',
#   '给',
#   '宝宝',
#   '讲述',
#   '效果',
#   '不错',
#   '呢',
#   '只是',
#   '用',
#   '了',
#   '元',
#   '多',
#   '钱',
#   '就',
#   '可以',
#   '享受',
#   '美妙',
#   '的',
#   '故事',
#   '和',
#   '亲子',
#   '的',
#   '时刻',
#   '是不是',
#   '物超所值',
#   '呢',
#   '我',
#   '和',
#   '女儿',
#   '都',
#   '是',
#   '拇指',
#   '姑娘',
#   '的',
#   '忠实',
#   '书迷',
#   '这套',
#   '的',
#   '其他',
#   '图书',
#   '也',
#   '统统',
#   '买下',
#   '闲',
#   '了',
#   '细读',
#   '其乐融融'],
#  ['是',
#   '一本',
#   '实用',
#   '而',
#   '简明',
#   '的',
#   '设计',
#   '参考',
#   '书籍',
#   '该书',
#   '详细',
#   '阐述',
#   '空调',
#   '技术',
#   '的',
#   '原理',
#   '与',
#   '参考',
#   '知识',
#   '各类',
#   '建筑物',
#   '空调',
#   '的',
#   '设计',
#   '特点',
#   '与',
#   '空调',
#   '方式',
#   '空调',
#   '系统',
#   '的',
#   '设计',
#   '方法',
#   '与',
#   '步骤',
#   '冷',
#   '热源',
#   '的',
#   '方式',
#   '与',
#   '特点',
#   '空调',
#   '系统',
#   '自动控制',
#   '与',
#   '监测',
#   '的',
#   '典型',
#   '方案',
#   '等',
#   '同时',
#   '也',
#   '充分',
#   '反应',
#   '空调',
#   '设计',
#   '近年来',
#   '的',
#   '进步',
#   '与',
#   '发展',
#   '本书',
#   '可',
#   '供',
#   '从事',
#   '空调',
#   '设计',
#   '营销',
#   '安装',
#   '人员',
#   '和',
#   '运行',
#   '管理人员',
#   '参考',
#   '也',
#   '可供',
#   '建筑',
#   '环境',
#   '与',
#   '设备',
#   '工程',
#   '专业',
#   '的',
#   '本科生',
#   '研究生',
#   '设计',
#   '时',
#   '参考'],
#  ...]

# %% [markdown]
# ## skip-gram构建词向量

# %%
#skip-gram构建词向量
skip_model = Word2Vec(sentences=words_list,sg=1 ,negative=10,vector_size=500, window=5, min_count=1, workers=4)
skip_model.save("skip.model")
skip_model = Word2Vec.load("skip.model")
# Out:
# 2022-06-03 13:45:29,121:INFO:collecting all words and their counts
# 2022-06-03 13:45:29,123:INFO:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-06-03 13:45:29,191:INFO:PROGRESS: at sentence #10000, processed 379631 words, keeping 29235 word types
# 2022-06-03 13:45:29,237:INFO:PROGRESS: at sentence #20000, processed 666652 words, keeping 38407 word types
# 2022-06-03 13:45:29,284:INFO:PROGRESS: at sentence #30000, processed 867324 words, keeping 42195 word types
# 2022-06-03 13:45:29,322:INFO:PROGRESS: at sentence #40000, processed 1066310 words, keeping 47477 word types
# 2022-06-03 13:45:29,360:INFO:PROGRESS: at sentence #50000, processed 1242441 words, keeping 50332 word types
# 2022-06-03 13:45:29,438:INFO:collected 63744 word types from a corpus of 1722838 raw words and 60000 sentences
# 2022-06-03 13:45:29,438:INFO:Creating a fresh vocabulary
# 2022-06-03 13:45:29,656:INFO:Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 63744 unique words (100.00% of original 63744, drops 0)', 'datetime': '2022-06-03T13:45:29.656929', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2022-06-03 13:45:29,656:INFO:Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1722838 word corpus (100.00% of original 1722838, drops 0)', 'datetime': '2022-06-03T13:45:29.656929', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2022-06-03 13:45:30,005:INFO:deleting the raw counts dictionary of 63744 items
# 2022-06-03 13:45:30,006:INFO:sample=0.001 downsamples 37 most-common words
# 2022-06-03 13:45:30,007:INFO:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1416646.0217998463 word corpus (82.2%% of prior 1722838)', 'datetime': '2022-06-03T13:45:30.007458', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2022-06-03 13:45:30,585:INFO:estimated required memory for 63744 words and 500 dimensions: 286848000 bytes
# 2022-06-03 13:45:30,585:INFO:resetting layer weights
# 2022-06-03 13:45:30,768:INFO:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-06-03T13:45:30.768543', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'build_vocab'}
# 2022-06-03 13:45:30,769:INFO:Word2Vec lifecycle event {'msg': 'training model with 4 workers on 63744 vocabulary and 500 features, using sg=1 hs=0 sample=0.001 negative=10 window=5 shrink_windows=True', 'datetime': '2022-06-03T13:45:30.769542', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2022-06-03 13:45:31,986:INFO:EPOCH 0 - PROGRESS: at 1.53% examples, 61160 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:33,020:INFO:EPOCH 0 - PROGRESS: at 4.30% examples, 80763 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:34,026:INFO:EPOCH 0 - PROGRESS: at 16.50% examples, 95566 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:35,045:INFO:EPOCH 0 - PROGRESS: at 25.54% examples, 108018 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:36,063:INFO:EPOCH 0 - PROGRESS: at 36.79% examples, 110413 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:37,092:INFO:EPOCH 0 - PROGRESS: at 49.87% examples, 112622 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:38,121:INFO:EPOCH 0 - PROGRESS: at 62.03% examples, 113295 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:39,207:INFO:EPOCH 0 - PROGRESS: at 81.77% examples, 117942 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:40,225:INFO:EPOCH 0 - PROGRESS: at 89.81% examples, 120204 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:41,356:INFO:EPOCH 0 - PROGRESS: at 94.18% examples, 119036 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:42,515:INFO:EPOCH 0 - PROGRESS: at 98.99% examples, 118594 words/s, in_qsize 3, out_qsize 1
# 2022-06-03 13:45:42,593:INFO:EPOCH 0: training on 1722838 raw words (1417210 effective words) took 11.8s, 119928 effective words/s
# 2022-06-03 13:45:43,828:INFO:EPOCH 1 - PROGRESS: at 2.20% examples, 86754 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:44,856:INFO:EPOCH 1 - PROGRESS: at 8.73% examples, 105420 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:45,854:INFO:EPOCH 1 - PROGRESS: at 20.82% examples, 113198 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:46,909:INFO:EPOCH 1 - PROGRESS: at 27.87% examples, 116729 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:47,910:INFO:EPOCH 1 - PROGRESS: at 42.18% examples, 120319 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:48,988:INFO:EPOCH 1 - PROGRESS: at 58.04% examples, 123538 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:49,993:INFO:EPOCH 1 - PROGRESS: at 76.83% examples, 128692 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:51,098:INFO:EPOCH 1 - PROGRESS: at 88.39% examples, 128717 words/s, in_qsize 8, out_qsize 0
# 2022-06-03 13:45:52,143:INFO:EPOCH 1 - PROGRESS: at 93.00% examples, 128310 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:53,215:INFO:EPOCH 1 - PROGRESS: at 98.70% examples, 130198 words/s, in_qsize 4, out_qsize 0
# 2022-06-03 13:45:53,431:INFO:EPOCH 1: training on 1722838 raw words (1416576 effective words) took 10.8s, 130647 effective words/s
# 2022-06-03 13:45:54,508:INFO:EPOCH 2 - PROGRESS: at 2.20% examples, 100498 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:55,597:INFO:EPOCH 2 - PROGRESS: at 12.65% examples, 124744 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:56,773:INFO:EPOCH 2 - PROGRESS: at 24.49% examples, 130395 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:57,780:INFO:EPOCH 2 - PROGRESS: at 37.55% examples, 136181 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:58,780:INFO:EPOCH 2 - PROGRESS: at 53.23% examples, 138863 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:45:59,806:INFO:EPOCH 2 - PROGRESS: at 69.53% examples, 140944 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:00,821:INFO:EPOCH 2 - PROGRESS: at 84.09% examples, 139167 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:01,849:INFO:EPOCH 2 - PROGRESS: at 90.45% examples, 137006 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:02,873:INFO:EPOCH 2 - PROGRESS: at 94.83% examples, 135235 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:03,901:INFO:EPOCH 2 - PROGRESS: at 98.70% examples, 132262 words/s, in_qsize 4, out_qsize 0
# 2022-06-03 13:46:04,114:INFO:EPOCH 2: training on 1722838 raw words (1416816 effective words) took 10.7s, 132751 effective words/s
# 2022-06-03 13:46:05,173:INFO:EPOCH 3 - PROGRESS: at 2.20% examples, 101601 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:06,295:INFO:EPOCH 3 - PROGRESS: at 12.65% examples, 124223 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:07,344:INFO:EPOCH 3 - PROGRESS: at 23.46% examples, 127289 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:08,349:INFO:EPOCH 3 - PROGRESS: at 33.31% examples, 130306 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:09,358:INFO:EPOCH 3 - PROGRESS: at 45.49% examples, 128080 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:10,365:INFO:EPOCH 3 - PROGRESS: at 58.76% examples, 127947 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:11,447:INFO:EPOCH 3 - PROGRESS: at 76.83% examples, 130074 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:12,526:INFO:EPOCH 3 - PROGRESS: at 88.15% examples, 129150 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:13,587:INFO:EPOCH 3 - PROGRESS: at 92.73% examples, 128509 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:14,625:INFO:EPOCH 3 - PROGRESS: at 96.61% examples, 126114 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:15,248:INFO:EPOCH 3: training on 1722838 raw words (1416739 effective words) took 11.1s, 127291 effective words/s
# 2022-06-03 13:46:16,334:INFO:EPOCH 4 - PROGRESS: at 2.21% examples, 98677 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:17,341:INFO:EPOCH 4 - PROGRESS: at 8.85% examples, 113338 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:18,340:INFO:EPOCH 4 - PROGRESS: at 22.03% examples, 124115 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:19,365:INFO:EPOCH 4 - PROGRESS: at 28.79% examples, 124116 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:20,409:INFO:EPOCH 4 - PROGRESS: at 41.40% examples, 122282 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:21,565:INFO:EPOCH 4 - PROGRESS: at 54.87% examples, 120136 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:22,621:INFO:EPOCH 4 - PROGRESS: at 68.57% examples, 120333 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:23,636:INFO:EPOCH 4 - PROGRESS: at 83.52% examples, 121423 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:24,643:INFO:EPOCH 4 - PROGRESS: at 90.11% examples, 121663 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:25,663:INFO:EPOCH 4 - PROGRESS: at 94.18% examples, 120809 words/s, in_qsize 7, out_qsize 0
# 2022-06-03 13:46:26,685:INFO:EPOCH 4 - PROGRESS: at 98.70% examples, 120795 words/s, in_qsize 4, out_qsize 0
# 2022-06-03 13:46:26,892:INFO:EPOCH 4: training on 1722838 raw words (1416303 effective words) took 11.6s, 121590 effective words/s
# 2022-06-03 13:46:26,892:INFO:Word2Vec lifecycle event {'msg': 'training on 8614190 raw words (7083644 effective words) took 56.1s, 126202 effective words/s', 'datetime': '2022-06-03T13:46:26.892084', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2022-06-03 13:46:26,892:INFO:Word2Vec lifecycle event {'params': 'Word2Vec<vocab=63744, vector_size=500, alpha=0.025>', 'datetime': '2022-06-03T13:46:26.892084', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 2022-06-03 13:46:26,892:INFO:Word2Vec lifecycle event {'fname_or_handle': 'skip.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-06-03T13:46:26.892084', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'saving'}
# 2022-06-03 13:46:26,902:INFO:storing np array 'vectors' to skip.model.wv.vectors.npy
# 2022-06-03 13:46:27,063:INFO:storing np array 'syn1neg' to skip.model.syn1neg.npy
# 2022-06-03 13:46:27,246:INFO:not storing attribute cum_table
# 2022-06-03 13:46:27,287:INFO:saved skip.model
# 2022-06-03 13:46:27,288:INFO:loading Word2Vec object from skip.model
# 2022-06-03 13:46:27,310:INFO:loading wv recursively from skip.model.wv.* with mmap=None
# 2022-06-03 13:46:27,310:INFO:loading vectors from skip.model.wv.vectors.npy with mmap=None
# 2022-06-03 13:46:27,349:INFO:loading syn1neg from skip.model.syn1neg.npy with mmap=None
# 2022-06-03 13:46:27,539:INFO:setting ignored attribute cum_table to None
# 2022-06-03 13:46:28,156:INFO:Word2Vec lifecycle event {'fname': 'skip.model', 'datetime': '2022-06-03T13:46:28.156240', 'gensim': '4.2.0', 'python': '3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'loaded'}

# %%
#查看与给定词相似度最高的10个词
sims = skip_model.wv.most_similar('孩子', topn=10) #看出skip-gram训练的词向量要比cbow好
sims
# Out:
# [('宝宝', 0.8033363819122314),
#  ('小孩', 0.7904739379882812),
#  ('父母', 0.7752928733825684),
#  ('小孩子', 0.7720273733139038),
#  ('小朋友', 0.7691418528556824),
#  ('儿子', 0.7557196617126465),
#  ('大人', 0.7486639022827148),
#  ('女儿', 0.7316305637359619),
#  ('妈妈', 0.7271788716316223),
#  ('家长', 0.726297914981842)]

# %% [markdown]
# ## 词向量可视化展示

# %%
from collections import Counter
#统计词频
words_all_list = []
for word_list in words_list:
    for word in word_list:
        if len(word)!=1:
            words_all_list.append(word)
counter = Counter(words_all_list)
#按照词频降序排列取前100个
words_freq = sorted(list(counter.items()),key = lambda x:x[1],reverse=True)
words_top100=list(dict(words_freq[:100]).keys())
#获得词频前100的词的词向量
vectors_top100 = skip_model.wv[words_top100]
vectors_top100
# Out:
# array([[ 0.03945588,  0.2260414 ,  0.5312613 , ..., -0.20017415,
#         -0.18433292,  0.25928998],
#        [-0.21150139, -0.05781301,  0.10963856, ..., -0.29589334,
#         -0.09175484,  0.40616688],
#        [ 0.23011234, -0.0096214 ,  0.40407556, ..., -0.06700508,
#          0.01466223,  0.20175944],
#        ...,
#        [-0.10924839, -0.0689744 ,  0.30684236, ..., -0.24626034,
#         -0.08534218,  0.06289537],
#        [ 0.06461856, -0.09776758,  0.16907476, ..., -0.46900275,
#         -0.01572469,  0.3328827 ],
#        [-0.12108823,  0.03295616,  0.26289925, ..., -0.2262587 ,
#         -0.44729015, -0.07150188]], dtype=float32)

# %%
#使用PCA降维得到2维词向量
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
word_2d = pca.fit_transform(vectors_top100)
#词向量可视化展示
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #图中文字体设置为黑体
plt.rcParams['axes.unicode_minus']=False #负值显示
plt.figure(figsize=(20,10))
plt.scatter(word_2d[:,0],word_2d[:,1])
for i in range(word_2d.shape[0]):
    plt.text(word_2d[i,0]*1.05, word_2d[i,1]*1.05, words_top100[i], fontsize=10, color = "r",  weight = "light", verticalalignment='center', horizontalalignment='right',rotation=0) #给散点加标签
plt.savefig('word_plot.png', dpi=300, bbox_inches='tight')
